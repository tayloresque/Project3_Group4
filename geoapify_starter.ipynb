# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import os

# Import the GeoApify API key
from api_keys import geoapify_key

# %%
import json

# Set parameters to search for a hotel
params = {
    "categories": "accommodation.hotel",
    "limit": 100,
    "apiKey" : geoapify_key
}

lat = 36
lng = -119
radius = 1000000
   
params["filter"] = f"circle:{lng},{lat},{radius}"
params["bias"] = f"proximity:{lng},{lat}"
    
base_url = "https://api.geoapify.com/v2/places?"

name_address = requests.get(base_url, params=params)
    
json_data = json.dumps(name_address.json(), indent=4)
print(json_data)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Best Western Porterville Inn",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Porterville",
#                 "postcode": "93257",
#                 "street": "West Montgomery Avenue",
#                 "lon": -119.02411246387025,
#                 "lat": 36.0504787,
#                 "state_code": "CA",
#                 "formatted": "Best Western Porterville Inn, West Montgomery Avenue, Porterville, CA 93257, United States of America",
#                 "address_line1": "Best Western Porterville Inn",
#                 "address_line2": "West Montgomery Avenue, Porterville, CA 93257, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Best Western Porterville Inn",
#                         "brand": "Best Western",
#                         "osm_id": 924363448,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "brand:wikidata": "Q830334"
#                     }
#                 },
#                 "distance": 5950,
#                 "place_id": "51e836f8cd86c15dc0594810375274064240f00102f901b8aa18370000000092031c42657374205765737465726e20506f7274657276696c6c6520496e6e"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.02385281791396,
#                     36.05042483986523
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Holiday Inn Express & Suites Porterville",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Porterville",
#                 "postcode": "93257",
#                 "street": "South Jaye Street",
#                 "housenumber": "840",
#                 "lon": -119.02561263823489,
#                 "lat": 36.0501737,
#                 "state_code": "CA",
#                 "formatted": "Holiday Inn Express & Suites Porterville, 840 South Jaye Street, Porterville, CA 93257, United States of America",
#                 "address_line1": "Holiday Inn Express & Suites Porterville",
#                 "address_line2": "840 South Jaye Street, Porterville, CA 93257, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Holiday Inn Express & Suites Porterville",
#                         "brand": "Holiday Inn Express & Suites",
#                         "osm_id": 930531944,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "addr:city": "Porterville",
#                         "addr:state": "CA",
#                         "addr:street": "South Jaye Street",
#                         "addr:postcode": 93257,
#                         "brand:wikidata": "Q5880423",
#                         "brand:wikipedia": "en:Holiday Inn Express",
#                         "addr:housenumber": 840
#                     }
#                 },
#                 "distance": 6009,
#                 "place_id": "51209d6c9fa3c15dc0590610cf176d064240f00102f90168ca763700000000920328486f6c6964617920496e6e204578707265737320262053756974657320506f7274657276696c6c65"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.02561174017728,
#                     36.05020425425032
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Best Western Exeter Inn & Suites",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Exeter",
#                 "postcode": "93221",
#                 "street": "South Kaweah Avenue",
#                 "housenumber": "805",
#                 "lon": -119.1357126,
#                 "lat": 36.2876592,
#                 "state_code": "CA",
#                 "formatted": "Best Western Exeter Inn & Suites, 805 South Kaweah Avenue, Exeter, CA 93221, United States of America",
#                 "address_line1": "Best Western Exeter Inn & Suites",
#                 "address_line2": "805 South Kaweah Avenue, Exeter, CA 93221, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "internet_access"
#                 ],
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "osm_id": 4698792699,
#                         "name:fr": "Best Western Exeter Inn & Suites",
#                         "tourism": "hotel",
#                         "osm_type": "n",
#                         "addr:street": "South Kaweah Avenue",
#                         "addr:postcode": 93221,
#                         "internet_access": "wlan",
#                         "addr:housenumber": 805
#                     }
#                 },
#                 "distance": 34176,
#                 "place_id": "51eda9e683afc85dc05959b14304d2244240f00103f901fbe2111801000000"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.13571259999999,
#                     36.28765919976531
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Fairfield Inn & Suites by Marriott Visalia Tulare",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Tulare",
#                 "postcode": "93274",
#                 "street": "Golden State Highway",
#                 "housenumber": "1225",
#                 "lon": -119.3319047147939,
#                 "lat": 36.2231817,
#                 "state_code": "CA",
#                 "formatted": "Fairfield Inn & Suites by Marriott Visalia Tulare, 1225 Golden State Highway, Tulare, CA 93274, United States of America",
#                 "address_line1": "Fairfield Inn & Suites by Marriott Visalia Tulare",
#                 "address_line2": "1225 Golden State Highway, Tulare, CA 93274, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Fairfield Inn & Suites by Marriott Visalia Tulare",
#                         "brand": "Fairfield Inn & Suites",
#                         "osm_id": 1058739459,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "addr:city": "Tulare",
#                         "addr:state": "CA",
#                         "addr:street": "Hillman Street",
#                         "addr:postcode": 93274,
#                         "official_name": "Fairfield Inn & Suites by Marriott",
#                         "brand:wikidata": "Q5430314",
#                         "addr:housenumber": 1225
#                     }
#                 },
#                 "distance": 38776,
#                 "place_id": "51b3bbf1ed3dd55dc059586b3a31911c4240f00102f90103151b3f00000000920331466169726669656c6420496e6e202620537569746573206279204d617272696f747420566973616c69612054756c617265"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.33190487486608,
#                     36.223180917286925
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Comfort Suites Tulare",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Tulare",
#                 "postcode": "93274",
#                 "street": "North Blackstone Street",
#                 "housenumber": "1021",
#                 "lon": -119.33383444790823,
#                 "lat": 36.22249035,
#                 "state_code": "CA",
#                 "formatted": "Comfort Suites Tulare, 1021 North Blackstone Street, Tulare, CA 93274, United States of America",
#                 "address_line1": "Comfort Suites Tulare",
#                 "address_line2": "1021 North Blackstone Street, Tulare, CA 93274, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel"
#                 ],
#                 "details": [],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "area": "yes",
#                         "name": "Comfort Suites Tulare",
#                         "osm_id": 924801816,
#                         "tourism": "hotel",
#                         "osm_type": "w",
#                         "addr:city": "Tulare",
#                         "addr:street": "North Blackstone Street",
#                         "addr:housenumber": 1021
#                     }
#                 },
#                 "distance": 38861,
#                 "place_id": "51d7279a655dd55dc059d9d466a6791c4240f00102f901185b1f3700000000920315436f6d666f7274205375697465732054756c617265"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.33382549337635,
#                     36.22246246357981
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Best Western Town and Country Suites",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Tulare",
#                 "postcode": "93274",
#                 "street": "North Blackstone Street",
#                 "lon": -119.33404954773698,
#                 "lat": 36.22287645,
#                 "state_code": "CA",
#                 "formatted": "Best Western Town and Country Suites, North Blackstone Street, Tulare, CA 93274, United States of America",
#                 "address_line1": "Best Western Town and Country Suites",
#                 "address_line2": "North Blackstone Street, Tulare, CA 93274, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel"
#                 ],
#                 "details": [],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Best Western Town and Country Suites",
#                         "osm_id": 924802031,
#                         "tourism": "hotel",
#                         "osm_type": "w"
#                     }
#                 },
#                 "distance": 38920,
#                 "place_id": "5124c7d72f68d55dc059058116e6841c4240f00102f901ef5b1f370000000092032442657374205765737465726e20546f776e20616e6420436f756e74727920537569746573"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.33448406288204,
#                     36.22280574892833
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "La Quinta Inn & Suites by Wyndham Tulare",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "California",
#                 "county": "Tulare County",
#                 "city": "Tulare",
#                 "postcode": "93274",
#                 "street": "Cherry Court",
#                 "housenumber": "1500",
#                 "lon": -119.3376288097642,
#                 "lat": 36.2274441,
#                 "state_code": "CA",
#                 "formatted": "La Quinta Inn & Suites by Wyndham Tulare, 1500 Cherry Court, Tulare, CA 93274, United States of America",
#                 "address_line1": "La Quinta Inn & Suites by Wyndham Tulare",
#                 "address_line2": "1500 Cherry Court, Tulare, CA 93274, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "La Quinta Inn & Suites by Wyndham Tulare",
#                         "osm_id": 933133846,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "addr:city": "Tulare",
#                         "addr:state": "CA",
#                         "addr:street": "Cherry Court",
#                         "addr:postcode": 93274,
#                         "addr:housenumber": 1500
#                     }
#                 },
#                 "distance": 39489,
#                 "place_id": "516e27fd839ad55dc0595530c9131e1d4240f00102f901167e9e37000000009203284c61205175696e746120496e6e2026205375697465732062792057796e6468616d2054756c617265"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -119.33755588266442,
#                     36.227480386006086
#                 ]
#             }
#         }
#     ]
# }
