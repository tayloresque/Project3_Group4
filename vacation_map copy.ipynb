# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import os

# Import the Priceline API key
from api_keys import priceline_api_key

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"HOTEL"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Pacific Coast Roadhouse, Surestay Collection BY Best Western - San Simeon, CA",
#         "id": "2211905",
#         "cityID": "3000002266",
#         "type": "HOTEL",
#         "lat": 35.61403,
#         "lon": -121.1449,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Simeon",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400488.75,
#         "radius": 57.9,
#         "rank": 11.810303,
#         "rank2": 99.55961608886719,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.16622,
#         "country": "US",
#         "address": "9280 CASTILLO DRIVE",
#         "zip": "93452",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Pacific Coast Roadhouse, Surestay Collection BY Best Western",
#         "displayLine2": "San Simeon, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Resorts World Catskills - Monticello, NY",
#         "id": "83134405",
#         "cityID": "3000016109",
#         "type": "HOTEL",
#         "lat": 41.657145,
#         "lon": -74.647719,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Monticello",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 400470.25,
#         "radius": 25.0,
#         "rank": 1.0,
#         "rank2": 99.53812408447266,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.147905,
#         "country": "US",
#         "address": "888 RESORTS WORLD DRIVE",
#         "zip": "12701",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Resorts World Catskills",
#         "displayLine2": "Monticello, New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ka'anapali Beach Hotel - Lahaina, HI",
#         "id": "55374",
#         "cityID": "3000004056",
#         "type": "HOTEL",
#         "lat": 20.92363885,
#         "lon": -156.69370919,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lahaina",
#         "stateCode": "HI",
#         "provinceName": "Hawaii",
#         "score": 400379.5,
#         "radius": 42.2,
#         "rank": 13.869067,
#         "rank2": 99.43313598632812,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.338116,
#         "country": "US",
#         "address": "2525 KAANAPALI PARKWAY",
#         "zip": "96761",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -10.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Ka'anapali Beach Hotel",
#         "displayLine2": "Lahaina, Hawaii",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "L\u00bfauberge Casino Resort Lake Charles - Lake Charles, LA",
#         "id": "13051304",
#         "cityID": "3000008374",
#         "type": "HOTEL",
#         "lat": 30.20676,
#         "lon": -93.258332,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lake Charles",
#         "stateCode": "LA",
#         "provinceName": "Louisiana",
#         "score": 400273.4,
#         "radius": 13.4,
#         "rank": 15.117631,
#         "rank2": 99.3105239868164,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.387842,
#         "country": "US",
#         "address": "777 AVENUE L\u00bfAUBERGE",
#         "zip": "70601",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "L\u00bfauberge Casino Resort Lake Charles",
#         "displayLine2": "Lake Charles, Louisiana",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Sunrise Resort Motel South - Clearwater Beach, FL",
#         "id": "18620004",
#         "cityID": "3000003143",
#         "type": "HOTEL",
#         "lat": 27.9739260000001,
#         "lon": -82.8282869999999,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Clearwater Beach",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 400228.3,
#         "radius": 21.3,
#         "rank": 11.810301,
#         "rank2": 99.25850677490234,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.173634,
#         "country": "US",
#         "address": "229 CORONADO DRIVE",
#         "zip": "33767",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Sunrise Resort Motel South",
#         "displayLine2": "Clearwater Beach, Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Americana Inn Motel - South San Francisco, CA",
#         "id": "43042606",
#         "cityID": "3000002333",
#         "type": "HOTEL",
#         "lat": 37.6514166,
#         "lon": -122.43103314,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "South San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400227.47,
#         "radius": 12.3,
#         "rank": 11.811775,
#         "rank2": 99.25753784179688,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.00555,
#         "country": "US",
#         "address": "760 EL CAMINO REAL",
#         "zip": "94080",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Americana Inn Motel",
#         "displayLine2": "South San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Sophie Station Suites - Fairbanks, AK",
#         "id": "56725",
#         "cityID": "3000000060",
#         "type": "HOTEL",
#         "lat": 64.83252,
#         "lon": -147.81251,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Fairbanks",
#         "stateCode": "AK",
#         "provinceName": "Alaska",
#         "score": 400214.3,
#         "radius": 12.1,
#         "rank": 11.810301,
#         "rank2": 99.24235534667969,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.073864,
#         "country": "US",
#         "address": "1717 UNIVERSITY AVENUE",
#         "zip": "99709",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -8.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Sophie Station Suites",
#         "displayLine2": "Fairbanks, Alaska",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Budget Host - Denton, TX",
#         "id": "2186405",
#         "cityID": "3000021100",
#         "type": "HOTEL",
#         "lat": 33.19427,
#         "lon": -97.11797,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Denton",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 400214.3,
#         "radius": 51.2,
#         "rank": 11.810301,
#         "rank2": 99.24235534667969,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.088646,
#         "country": "US",
#         "address": "1500 DALLAS DRIVE",
#         "zip": "76205",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Budget Host",
#         "displayLine2": "Denton, Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Wine Country Inn - Palisade, CO",
#         "id": "14130004",
#         "cityID": "3000002719",
#         "type": "HOTEL",
#         "lat": 39.119309,
#         "lon": -108.364976,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Palisade",
#         "stateCode": "CO",
#         "provinceName": "Colorado",
#         "score": 400161.4,
#         "radius": 25.0,
#         "rank": 11.813059,
#         "rank2": 99.18133544921875,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.048014,
#         "country": "US",
#         "address": "777 GRANDE RIVER DRIVE",
#         "zip": "81526",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Wine Country Inn",
#         "displayLine2": "Palisade, Colorado",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ingleside Motel - Athens, TN",
#         "id": "121538803",
#         "cityID": "3000020336",
#         "type": "HOTEL",
#         "lat": 35.44329,
#         "lon": -84.63408,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Athens",
#         "stateCode": "TN",
#         "provinceName": "Tennessee",
#         "score": 400138.0,
#         "radius": 24.2,
#         "rank": 0.5,
#         "rank2": 99.15431213378906,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.00739,
#         "country": "US",
#         "address": "2214 CONGRESS PARKWAY S",
#         "zip": "37303",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Ingleside Motel",
#         "displayLine2": "Athens, Tennessee",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

hotel_data = pd.DataFrame(dictionary_data)

hotel_data.head()
# Out:
#                                             itemName        id      cityID  \
# 0  Pacific Coast Roadhouse, Surestay Collection B...   2211905  3000002266
# 1           Resorts World Catskills - Monticello, NY  83134405  3000016109
# 2               Ka'anapali Beach Hotel - Lahaina, HI     55374  3000004056
# 3  L¿auberge Casino Resort Lake Charles - Lake Ch...  13051304  3000008374
# 4  Sunrise Resort Motel South - Clearwater Beach, FL  18620004  3000003143
#
#     type        lat         lon  proximity savedTravelStartDate  \
# 0  HOTEL  35.614030 -121.144900        0.0                 None
# 1  HOTEL  41.657145  -74.647719        0.0                 None
# 2  HOTEL  20.923639 -156.693709        0.0                 None
# 3  HOTEL  30.206760  -93.258332        0.0                 None
# 4  HOTEL  27.973926  -82.828287        0.0                 None
#
#   savedTravelEndDate          cityName  ... poiCategoryTypeId poiCategoryName  \
# 0               None        San Simeon  ...                 0            None
# 1               None        Monticello  ...                 0            None
# 2               None           Lahaina  ...                 0            None
# 3               None      Lake Charles  ...                 0            None
# 4               None  Clearwater Beach  ...                 0            None
#
#    poiID  seType  gmtOffset        entered  highlightedName  \
# 0   None    None       -7.0  united states             None
# 1   None    None       -4.0  united states             None
# 2   None    None      -10.0  united states             None
# 3   None    None       -5.0  united states             None
# 4   None    None       -4.0  united states             None
#
#                                         displayLine1  \
# 0  Pacific Coast Roadhouse, Surestay Collection B...
# 1                            Resorts World Catskills
# 2                             Ka'anapali Beach Hotel
# 3               L¿auberge Casino Resort Lake Charles
# 4                         Sunrise Resort Motel South
#
#                 displayLine2 fromSavedSearch
# 0     San Simeon, California           False
# 1       Monticello, New York           False
# 2            Lahaina, Hawaii           False
# 3    Lake Charles, Louisiana           False
# 4  Clearwater Beach, Florida           False
#
# [5 rows x 34 columns]

# %%
hotel_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
hotel_data['name'] = hotel_data['itemName'].str.split('-').str[0]
hotel_data['city'] = hotel_data['itemName'].str.split('-').str[1].str.split(',').str[0]
hotel_data['state'] = hotel_data['itemName'].str.split('-').str[1].str.split(',').str[1]

column_to_select = ['name',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country' 
                    ]

hotel_data_select = hotel_data[column_to_select]

hotel_data_select.head()
# Out:
#                                                 name               city state  \
# 0  Pacific Coast Roadhouse, Surestay Collection B...         San Simeon    CA
# 1                           Resorts World Catskills          Monticello    NY
# 2                            Ka'anapali Beach Hotel             Lahaina    HI
# 3              L¿auberge Casino Resort Lake Charles        Lake Charles    LA
# 4                        Sunrise Resort Motel South    Clearwater Beach    FL
#
#          lat         lon      score       rank      rank2  globalScore country
# 0  35.614030 -121.144900  400488.75  11.810303  99.559616         30.0      US
# 1  41.657145  -74.647719  400470.25   1.000000  99.538124         30.0      US
# 2  20.923639 -156.693709  400379.50  13.869067  99.433136         30.0      US
# 3  30.206760  -93.258332  400273.40  15.117631  99.310524         30.0      US
# 4  27.973926  -82.828287  400228.30  11.810301  99.258507         30.0      US

# %%
hotel_data_select.dtypes
# Out:
# name            object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# name           0
# city           0
# state          0
# lat            0
# lon            0
# score          0
# rank           0
# rank2          0
# globalScore    0
# country        0
# dtype: int64

# %%
# # Create a folder named "data" if it doesn't exist
# if not os.path.exists("data"):
#     os.mkdir("data")

# # Save DataFrame to a CSV file inside the "data" folder
# file_path = os.path.join("data", "hotel.csv")
# hotel_data_clean.to_csv(file_path, index=False)

# print("DataFrame saved to 'data/hotel.csv' file.")

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"AIRPORT"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Orlando Intl Airport (MCO) , FL",
#         "id": "MCO",
#         "cityID": "3000003349",
#         "type": "AIRPORT",
#         "lat": 28.43113982264317,
#         "lon": -81.3092428479283,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Orlando",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 388071.7,
#         "radius": 33.7,
#         "rank": 56.13621,
#         "rank2": 86.16417694091797,
#         "globalScore": 78.25274,
#         "globalScoreReducedCityBoost": 62.42079,
#         "globalScoreWOHotelCountNormalize": 48.595905,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Orlando - Orlando Intl Airport (MCO)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Miami Intl Airport (MIA) , FL",
#         "id": "MIA",
#         "cityID": "3000003311",
#         "type": "AIRPORT",
#         "lat": 25.79507559880528,
#         "lon": -80.28296084528998,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Miami",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 387476.06,
#         "radius": 28.9,
#         "rank": 45.91389,
#         "rank2": 85.56851196289062,
#         "globalScore": 76.66467,
#         "globalScoreReducedCityBoost": 46.181736,
#         "globalScoreWOHotelCountNormalize": 39.20895,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Miami - Miami Intl Airport (MIA)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hollywood Intl Airport (FLL) , FL",
#         "id": "FLL",
#         "cityID": "3000003192",
#         "type": "AIRPORT",
#         "lat": 26.076856242450617,
#         "lon": -80.1512378481894,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Fort Lauderdale",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 385824.0,
#         "radius": 17.6,
#         "rank": 57.068672,
#         "rank2": 83.93750762939453,
#         "globalScore": 75.521675,
#         "globalScoreReducedCityBoost": 43.354076,
#         "globalScoreWOHotelCountNormalize": 37.50558,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Fort Lauderdale - Hollywood Intl Airport (FLL)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hartsfield-Jackson Atlanta Intl Airport (ATL) , GA",
#         "id": "ATL",
#         "cityID": "3000003496",
#         "type": "AIRPORT",
#         "lat": 33.64064398331116,
#         "lon": -84.42246632355115,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Atlanta",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 385106.7,
#         "radius": 37.0,
#         "rank": 42.474194,
#         "rank2": 83.23897552490234,
#         "globalScore": 76.96165,
#         "globalScoreReducedCityBoost": 51.29527,
#         "globalScoreWOHotelCountNormalize": 41.950603,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Atlanta - Hartsfield-Jackson Atlanta Intl Airport (ATL)",
#         "displayLine2": "Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Phoenix Sky Harbor Intl Airport (PHX) , AZ",
#         "id": "PHX",
#         "cityID": "3000001349",
#         "type": "AIRPORT",
#         "lat": 33.43546779687481,
#         "lon": -112.00379514445629,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Phoenix",
#         "stateCode": "AZ",
#         "provinceName": "Arizona",
#         "score": 384922.34,
#         "radius": 36.7,
#         "rank": 47.539833,
#         "rank2": 83.06039428710938,
#         "globalScore": 74.87271,
#         "globalScoreReducedCityBoost": 42.74244,
#         "globalScoreWOHotelCountNormalize": 37.122154,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Phoenix - Phoenix Sky Harbor Intl Airport (PHX)",
#         "displayLine2": "Arizona",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Tampa Intl Airport (TPA) , FL",
#         "id": "TPA",
#         "cityID": "3000003431",
#         "type": "AIRPORT",
#         "lat": 27.980050150536673,
#         "lon": -82.53468498015411,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Tampa",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 384829.56,
#         "radius": 21.6,
#         "rank": 46.03609,
#         "rank2": 82.97066497802734,
#         "globalScore": 75.06991,
#         "globalScoreReducedCityBoost": 41.70141,
#         "globalScoreWOHotelCountNormalize": 36.507195,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Tampa - Tampa Intl Airport (TPA)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "O'Hare Intl Airport (ORD) , IL",
#         "id": "ORD",
#         "cityID": "3000005381",
#         "type": "AIRPORT",
#         "lat": 41.9704762962616,
#         "lon": -87.9083988449066,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Chicago",
#         "stateCode": "IL",
#         "provinceName": "Illinois",
#         "score": 384373.75,
#         "radius": 21.7,
#         "rank": 46.816677,
#         "rank2": 82.53114318847656,
#         "globalScore": 76.78653,
#         "globalScoreReducedCityBoost": 47.541634,
#         "globalScoreWOHotelCountNormalize": 39.76,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Chicago - O'Hare Intl Airport (ORD)",
#         "displayLine2": "Illinois",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Seattle-Tacoma Intl Airport (SEA) , WA",
#         "id": "SEA",
#         "cityID": "3000023414",
#         "type": "AIRPORT",
#         "lat": 47.44927062064107,
#         "lon": -122.31113399152126,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Seattle",
#         "stateCode": "WA",
#         "provinceName": "Washington",
#         "score": 384369.62,
#         "radius": 28.0,
#         "rank": 41.146538,
#         "rank2": 82.52716827392578,
#         "globalScore": 74.76679,
#         "globalScoreReducedCityBoost": 42.604374,
#         "globalScoreWOHotelCountNormalize": 37.04834,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Seattle - Seattle-Tacoma Intl Airport (SEA)",
#         "displayLine2": "Washington",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "John F Kennedy Intl Airport (JFK) , NY",
#         "id": "JFK",
#         "cityID": "3000015923",
#         "type": "AIRPORT",
#         "lat": 40.639380746613675,
#         "lon": -73.77204034876185,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Jamaica",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 383816.53,
#         "radius": 14.0,
#         "rank": 51.016113,
#         "rank2": 81.9969711303711,
#         "globalScore": 77.9219,
#         "globalScoreReducedCityBoost": 50.513313,
#         "globalScoreWOHotelCountNormalize": 41.390118,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Jamaica - John F Kennedy Intl Airport (JFK)",
#         "displayLine2": "New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Los Angeles Intl Airport (LAX) , CA",
#         "id": "LAX",
#         "cityID": "3000001947",
#         "type": "AIRPORT",
#         "lat": 33.94310840336072,
#         "lon": -118.41060920960915,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 383285.66,
#         "radius": 22.3,
#         "rank": 58.362736,
#         "rank2": 81.49127960205078,
#         "globalScore": 76.51697,
#         "globalScoreReducedCityBoost": 44.505028,
#         "globalScoreWOHotelCountNormalize": 38.192566,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Los Angeles - Los Angeles Intl Airport (LAX)",
#         "displayLine2": "California",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

airport_data = pd.DataFrame(dictionary_data)

airport_data.head()
# Out:
#                                             itemName   id      cityID  \
# 0                    Orlando Intl Airport (MCO) , FL  MCO  3000003349
# 1                      Miami Intl Airport (MIA) , FL  MIA  3000003311
# 2                  Hollywood Intl Airport (FLL) , FL  FLL  3000003192
# 3  Hartsfield-Jackson Atlanta Intl Airport (ATL) ...  ATL  3000003496
# 4         Phoenix Sky Harbor Intl Airport (PHX) , AZ  PHX  3000001349
#
#       type        lat         lon  proximity savedTravelStartDate  \
# 0  AIRPORT  28.431140  -81.309243        0.0                 None
# 1  AIRPORT  25.795076  -80.282961        0.0                 None
# 2  AIRPORT  26.076856  -80.151238        0.0                 None
# 3  AIRPORT  33.640644  -84.422466        0.0                 None
# 4  AIRPORT  33.435468 -112.003795        0.0                 None
#
#   savedTravelEndDate         cityName  ... poiCategoryTypeId poiCategoryName  \
# 0               None          Orlando  ...                 0            None
# 1               None            Miami  ...                 0            None
# 2               None  Fort Lauderdale  ...                 0            None
# 3               None          Atlanta  ...                 0            None
# 4               None          Phoenix  ...                 0            None
#
#    poiID  seType  gmtOffset        entered  highlightedName  \
# 0   None    None       -4.0  united states             None
# 1   None    None       -4.0  united states             None
# 2   None    None       -4.0  united states             None
# 3   None    None       -4.0  united states             None
# 4   None    None       -7.0  united states             None
#
#                                         displayLine1  displayLine2  \
# 0               Orlando - Orlando Intl Airport (MCO)       Florida
# 1                   Miami - Miami Intl Airport (MIA)       Florida
# 2     Fort Lauderdale - Hollywood Intl Airport (FLL)       Florida
# 3  Atlanta - Hartsfield-Jackson Atlanta Intl Airp...       Georgia
# 4    Phoenix - Phoenix Sky Harbor Intl Airport (PHX)       Arizona
#
#   fromSavedSearch
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 34 columns]

# %%
airport_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
airport_data['name'] = airport_data['itemName'].str.split(',').str[0]
airport_data['city'] = airport_data['cityName']
airport_data['state'] = airport_data['displayLine2']

column_to_select = ['name',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country' 
                    ]

airport_data_select = airport_data[column_to_select]

airport_data_select.head()
# Out:
#                                              name             city    state  \
# 0                     Orlando Intl Airport (MCO)           Orlando  Florida
# 1                       Miami Intl Airport (MIA)             Miami  Florida
# 2                   Hollywood Intl Airport (FLL)   Fort Lauderdale  Florida
# 3  Hartsfield-Jackson Atlanta Intl Airport (ATL)           Atlanta  Georgia
# 4          Phoenix Sky Harbor Intl Airport (PHX)           Phoenix  Arizona
#
#          lat         lon      score       rank      rank2  globalScore country
# 0  28.431140  -81.309243  388071.70  56.136210  86.164177    78.252740      US
# 1  25.795076  -80.282961  387476.06  45.913890  85.568512    76.664670      US
# 2  26.076856  -80.151238  385824.00  57.068672  83.937508    75.521675      US
# 3  33.640644  -84.422466  385106.70  42.474194  83.238976    76.961650      US
# 4  33.435468 -112.003795  384922.34  47.539833  83.060394    74.872710      US

# %%
airport_data_select.dtypes
# Out:
# name            object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# name           0
# city           0
# state          0
# lat            0
# lon            0
# score          0
# rank           0
# rank2          0
# globalScore    0
# country        0
# dtype: int64

# %%
# # Create a folder named "data" if it doesn't exist
# if not os.path.exists("data"):
#     os.mkdir("data")

# # Save DataFrame to a CSV file inside the "data" folder
# file_path = os.path.join("data", "airport.csv")
# hotel_data_clean.to_csv(file_path, index=False)

# print("DataFrame saved to 'data/airport.csv' file.")
