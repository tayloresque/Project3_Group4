# %%
import requests
import json
import pandas as pd

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002244","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 313, 'marketSize': 464, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 39, 'cityCounts': {'3000002333': 5, '3000001520': 1, '3000002244': 13, '3000002010': 5, '3000001482': 4, '3000001527': 5, '3000002238': 4, '3000002259': 2}, 'clusterCounts': {'910050141': 6, '910003475': 5, '910051355': 10, '910051354': 5, '910051189': 1, '910003457': 2, '910051191': 4, '910051710': 2, '910051711': 2, '910051190': 2}, 'amenityCounts': {'KITCHEN': 14, 'FPRKING': 13, 'AIRSHUTTL': 23, 'SPA': 5, 'KIDFRIEND': 6, 'FBRKFST': 39, 'HOTTUB': 5, 'SUSTAIN': 34, 'FAMFRIEND': 33, 'FITSPA': 33, 'NSMKFAC': 39, 'HANDFAC': 39, 'PETALLOW': 20, 'ADULTONLY': 1, 'RESTRNT': 14, 'FINTRNT': 39, 'SPOOL': 11, 'HEALTHSVCS': 34}, 'starRatingCounts': {'2.5': 18, '3.5': 2, '2.0': 14, '3.0': 36, '4.0': 1}, 'brandIdCounts': {'22': 1, '12': 3, '72403': 2, '24': 1, '467304': 2, '0': 13, '1': 1, '87304': 2, '8': 1, '80': 2, '9': 4, '14702': 5, '216305': 2}, 'propertyTypeCo
# ...

# %%
SFdata={}
SFdata=data['hotels']
#SFdata

# %%
SFprices=[]
for hotel in SFdata:
    SFprices.append(hotel['ratesSummary'])
    #SFprices.append(hotel['location'])

# %%
SFprices_df=pd.DataFrame(SFprices)
SFprices_df.head()
# Out:
#   minPrice minCurrencyCode minStrikePrice  \
# 0    63.24             USD          74.40
# 1   103.00             USD         132.39
# 2   121.00             USD         156.85
# 3   127.81             USD         152.15
# 4   132.00             USD         170.25
#
#                                               pclnId  freeCancelableRateAvail  \
# 0  5826720D69A5F914CA870296E2D8C9FAAB8B0FEC57DF2C...                    False
# 1  24EC40BCEEB58913EF7956485D34C620C06661E41B2541...                    False
# 2  79EF99BE802B117E33BD122B381696E713B696F33340DF...                    False
# 3  6C944C09A3FC97035EDBCEC65E755B73084499C9C3151D...                     True
# 4  FCE41E370C11F2CA39E171D3A939621FDFBDF84FC3212F...                    False
#
#    payWhenYouStayAvailable                                    availablePromos  \
# 0                    False  [{'type': 'DISCOUNT', 'title': 'On Sale Now ->...
# 1                    False                                                NaN
# ...

# %%
columns_select=['minPrice', 'minStrikePrice', 'strikeThroughPrice',
                            'minRateSavingsPercentage', 'minRateStrikeThroughPrice']
SFprice_df_clean_fall=SFprices_df[columns_select]
SFprice_df_clean_fall
# Out:
#    minPrice minStrikePrice strikeThroughPrice  minRateSavingsPercentage  \
# 0     63.24          74.40              74.40                       NaN
# 1    103.00         132.39             132.39                      43.0
# 2    121.00         156.85             156.85                      23.0
# 3    127.81         152.15             152.15                       NaN
# 4    132.00         170.25             170.25                      34.0
# 5    132.00         171.21             171.21                      23.0
# 6    139.00            NaN                NaN                       NaN
# 7    140.00         180.08             180.08                      29.0
# 8    143.64         179.55             179.55                       NaN
# 9    151.09         193.50             193.50                       NaN
# 10   152.00         195.91             195.91                      30.0
# 11   152.24         169.15             169.15                       NaN
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2024-06-19","sort_order":"PRICE","location_id":"3000002244","date_checkin":"2024-06-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 222, 'marketSize': 464, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 30, 'cityCounts': {'3000002333': 3, '3000002244': 13, '3000002010': 2, '3000001482': 4, '3000001527': 3, '3000002238': 3, '3000002259': 2}, 'clusterCounts': {'910050141': 6, '910003475': 1, '910051355': 5, '910051354': 5, '910003457': 2, '910051191': 5, '910051710': 2, '910051190': 2, '910051711': 2}, 'amenityCounts': {'KITCHEN': 12, 'FPRKING': 9, 'AIRSHUTTL': 19, 'SPA': 5, 'KIDFRIEND': 7, 'FBRKFST': 30, 'HOTTUB': 3, 'SUSTAIN': 28, 'FAMFRIEND': 26, 'FITSPA': 23, 'NSMKFAC': 30, 'HANDFAC': 30, 'PETALLOW': 12, 'ADULTONLY': 1, 'RESTRNT': 12, 'FINTRNT': 30, 'SPOOL': 8, 'HEALTHSVCS': 28}, 'starRatingCounts': {'2.5': 18, '3.5': 4, '2.0': 12, '3.0': 26}, 'brandIdCounts': {'0': 11, '22': 1, '12': 2, '1': 2, '72403': 2, '24': 1, '87304': 1, '8': 1, '80': 2, '9': 2, '14702': 5}, 'propertyTypeCounts': {'218': 2, '208': 1, '204': 26, '205': 1}, 'propertyType': [{'typ
# ...

# %%
SFSummerdata={}
SFSummerdata=data['hotels']
SFSummerdata
# Out:
# [{'pclnId': 'CEB9D82697C2B564F723F0326AE3597CDFBDF84FC3212F9F9098EB03252A832EDEF1402DEA80ECF29D878B6B80AA90ECBABE56D5E8F0ACA1BDD50A3BEB59BA9D6250F41145ABD05FC3114465711A693DD7F5679ED7832A618A76B6D3C12ABA638CDB0A2B78049C16882EA30C6569D09C',
#   'hotelType': 'SOPQ',
#   'starRating': 3.5,
#   'location': {'address': {'cityName': 'San Francisco',
#     'provinceCode': 'CA',
#     'countryName': 'United States',
#     'isoCountryCode': 'US'},
#    'timeZone': 'America/Los_Angeles',
#    'neighborhoodId': '910051711',
#    'neighborhoodName': 'Civic Center South - South of Market',
#    'cityId': 3000002244,
#    'zoneId': '51711',
#    'zoneName': 'Civic Center South - South of Market Area',
#    'zoneType': 'Z',
#    'encLatLong': 'C16697495D827DA028EB4073A5A6A95DFD2EB104A29E429B466FF0606D5EB658'},
#   'hotelFeatures': {'hotelAmenityCodes': ['FBRKFST',
#     'FINTRNT',
#     'HEALTHSVCS',
#     'HANDFAC',
#     'NSMKFAC',
#     'SUSTAIN',
#     'HOTTUB',
#     'FAMFRIEND'],
# ...

# %%
SFSummerprices=[]
for hotel in SFSummerdata:
    SFSummerprices.append(hotel['ratesSummary'])
SFSummerprices
# Out:
# [{'minPrice': '106.00',
#   'minCurrencyCode': 'USD',
#   'minStrikePrice': '136.04',
#   'pclnId': 'CEB9D82697C2B564F723F0326AE3597CDFBDF84FC3212F9F9098EB03252A832EDEF1402DEA80ECF29D878B6B80AA90ECBABE56D5E8F0ACA1BDD50A3BEB59BA9D6250F41145ABD05FC3114465711A693DD7F5679ED7832A618A76B6D3C12ABA638CDB0A2B78049C16882EA30C6569D09C',
#   'freeCancelableRateAvail': False,
#   'payWhenYouStayAvailable': False,
#   'roomLeft': 2,
#   'gid': 3078,
#   'rateIdentifier': '45E10921C76A5218514FC40A5E998540CCC17695F757649BABDF4B779A2FCCA32EF0A84B6D6B4424273D2824BF427D28F52D5176950FADBBB7DD21BDDBE6C552ECD523A2E81B7D3B1A5748E2F948D3EE411F82D4D4A7F0EBE78132E7FB9D08E6E43A1CAD8D989F82',
#   'programName': 'Express_Deal',
#   'strikeThroughPrice': '136.04',
#   'merchandisingFlag': True,
#   'minRateSavingsPercentage': 33,
#   'ccNotRequiredAvailable': False,
#   'applePayRateAvailable': False,
#   'minRateStrikeThroughPrice': '158'},
#  {'minPrice': '143.00',
#   'minCurrencyCode': 'USD',
# ...

# %%
SFSummer_df=pd.DataFrame(SFSummerprices)
SFSummer_df.head()
# Out:
#   minPrice minCurrencyCode minStrikePrice  \
# 0   106.00             USD         136.04
# 1   143.00             USD         185.09
# 2   143.10             USD         159.00
# 3   151.99             USD            NaN
# 4   159.00             USD            NaN
#
#                                               pclnId  freeCancelableRateAvail  \
# 0  CEB9D82697C2B564F723F0326AE3597CDFBDF84FC3212F...                    False
# 1  F9C332E3859DB56F842ACE9D08B4D18C0960C191805211...                    False
# 2  7CD033398EDB4F82F8BEC74EE2C40E8CCE6C923ED9CDD3...                     True
# 3  D00DC08085BD51ECC40159EED66D222AC393FD7CC145AF...                     True
# 4  3EB38B7BBEAC553EFD1ACEDF8BE3CB69C06661E41B2541...                     True
#
#    payWhenYouStayAvailable  roomLeft   gid  \
# 0                    False       2.0  3078
# 1                    False       1.0  5736
# 2                    False       2.0  2943
# 3                     True       NaN  3848
# ...

# %%
columns_select=['minPrice', 'minStrikePrice', 'strikeThroughPrice',
                            'minRateSavingsPercentage', 'minRateStrikeThroughPrice']
SFSummer_df_clean=SFSummer_df[columns_select]
SFSummer_df_clean.head()
# Out:
#   minPrice minStrikePrice strikeThroughPrice  minRateSavingsPercentage  \
# 0   106.00         136.04             136.04                      33.0
# 1   143.00         185.09             185.09                      23.0
# 2   143.10         159.00             159.00                       NaN
# 3   151.99            NaN                NaN                       NaN
# 4   159.00            NaN                NaN                       NaN
#
#   minRateStrikeThroughPrice
# 0                       158
# 1                       185
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2024-02-19","sort_order":"PRICE","location_id":"3000002244","date_checkin":"2024-02-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 284, 'marketSize': 464, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 37, 'cityCounts': {'3000002333': 4, '3000001520': 2, '3000002244': 15, '3000002010': 2, '3000001482': 4, '3000001527': 5, '3000002238': 3, '3000002259': 2}, 'clusterCounts': {'910050141': 6, '910003475': 5, '910051355': 7, '910051354': 4, '910051189': 1, '910003457': 2, '910051191': 6, '910051710': 2, '910051190': 2, '910051711': 2}, 'amenityCounts': {'KITCHEN': 15, 'FPRKING': 11, 'AIRSHUTTL': 24, 'SPA': 5, 'KIDFRIEND': 6, 'FBRKFST': 37, 'HOTTUB': 3, 'SUSTAIN': 33, 'FAMFRIEND': 31, 'FITSPA': 30, 'NSMKFAC': 37, 'HANDFAC': 37, 'PETALLOW': 20, 'ADULTONLY': 1, 'RESTRNT': 13, 'FINTRNT': 37, 'SPOOL': 10, 'HEALTHSVCS': 34}, 'starRatingCounts': {'2.5': 21, '3.5': 4, '2.0': 15, '3.0': 32, '4.0': 1}, 'brandIdCounts': {'22': 1, '12': 4, '24': 1, '72403': 2, '467304': 2, '0': 13, '1': 1, '87304': 1, '8': 1, '80': 2, '9': 4, '14702': 5}, 'propertyTypeCounts': {'218':
# ...

# %%
SFWinterdata={}
SFWinterdata=data['hotels']
SFWinterdata
# Out:
# [{'hotelId': '2601305',
#   'name': 'Hotel Aura San Francisco Airport',
#   'brand': 'Independent',
#   'starRating': 3.0,
#   'location': {'address': {'addressLine1': '190 El Camino Real',
#     'cityName': 'San Bruno',
#     'provinceCode': 'CA',
#     'countryName': 'United States',
#     'zip': '94066',
#     'isoCountryCode': 'US'},
#    'longitude': -122.40854,
#    'latitude': 37.617611,
#    'timeZone': 'America/Los_Angeles',
#    'neighborhoodId': '910051354',
#    'neighborhoodName': 'SFO North - San Bruno',
#    'cityId': 3000002238,
#    'zoneId': '51354'},
#   'thumbnailUrl': 'https://mobileimg.priceline.com/htlimg/2601/2601305/thumbnail-150-square.jpg',
#   'hotelFeatures': {'hotelAmenityCodes': ['FBRKFST',
#     'FINTRNT',
#     'FPRKING',
#     'HEALTHSVCS',
#     'AIRSHUTTL',
#     'RESTRNT',
#     'HANDFAC',
#     'NSMKFAC',
#     'SUSTAIN',
#     'FAMFRIEND']},
#   'overallGuestRating': 8.2,
#   'totalReviewCount': 1226,
#   'proximity': 2.647958238106746,
# ...

# %%
SFWinterprices=[]
for hotel in SFSummerdata:
    SFWinterprices.append(hotel['ratesSummary'])
SFWinterprices
# Out:
# [{'minPrice': '106.00',
#   'minCurrencyCode': 'USD',
#   'minStrikePrice': '136.04',
#   'pclnId': 'CEB9D82697C2B564F723F0326AE3597CDFBDF84FC3212F9F9098EB03252A832EDEF1402DEA80ECF29D878B6B80AA90ECBABE56D5E8F0ACA1BDD50A3BEB59BA9D6250F41145ABD05FC3114465711A693DD7F5679ED7832A618A76B6D3C12ABA638CDB0A2B78049C16882EA30C6569D09C',
#   'freeCancelableRateAvail': False,
#   'payWhenYouStayAvailable': False,
#   'roomLeft': 2,
#   'gid': 3078,
#   'rateIdentifier': '45E10921C76A5218514FC40A5E998540CCC17695F757649BABDF4B779A2FCCA32EF0A84B6D6B4424273D2824BF427D28F52D5176950FADBBB7DD21BDDBE6C552ECD523A2E81B7D3B1A5748E2F948D3EE411F82D4D4A7F0EBE78132E7FB9D08E6E43A1CAD8D989F82',
#   'programName': 'Express_Deal',
#   'strikeThroughPrice': '136.04',
#   'merchandisingFlag': True,
#   'minRateSavingsPercentage': 33,
#   'ccNotRequiredAvailable': False,
#   'applePayRateAvailable': False,
#   'minRateStrikeThroughPrice': '158'},
#  {'minPrice': '143.00',
#   'minCurrencyCode': 'USD',
# ...

# %%
SFWinter_df=pd.DataFrame(SFWinterprices)
SFWinter_df.head()
# Out:
#   minPrice minCurrencyCode minStrikePrice  \
# 0   106.00             USD         136.04
# 1   143.00             USD         185.09
# 2   143.10             USD         159.00
# 3   151.99             USD            NaN
# 4   159.00             USD            NaN
#
#                                               pclnId  freeCancelableRateAvail  \
# 0  CEB9D82697C2B564F723F0326AE3597CDFBDF84FC3212F...                    False
# 1  F9C332E3859DB56F842ACE9D08B4D18C0960C191805211...                    False
# 2  7CD033398EDB4F82F8BEC74EE2C40E8CCE6C923ED9CDD3...                     True
# 3  D00DC08085BD51ECC40159EED66D222AC393FD7CC145AF...                     True
# 4  3EB38B7BBEAC553EFD1ACEDF8BE3CB69C06661E41B2541...                     True
#
#    payWhenYouStayAvailable  roomLeft   gid  \
# 0                    False       2.0  3078
# 1                    False       1.0  5736
# 2                    False       2.0  2943
# 3                     True       NaN  3848
# ...

# %%
columns_select=['minPrice', 'minStrikePrice', 'strikeThroughPrice',
                            'minRateSavingsPercentage', 'minRateStrikeThroughPrice']
SFWinter_df_clean=SFWinter_df[columns_select]
SFWinter_df_clean.head()
# Out:
#   minPrice minStrikePrice strikeThroughPrice  minRateSavingsPercentage  \
# 0   106.00         136.04             136.04                      33.0
# 1   143.00         185.09             185.09                      23.0
# 2   143.10         159.00             159.00                       NaN
# 3   151.99            NaN                NaN                       NaN
# 4   159.00            NaN                NaN                       NaN
#
#   minRateStrikeThroughPrice
# 0                       158
# 1                       185
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002250","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data= response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 348, 'marketSize': 653, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 54, 'cityCounts': {'3000002356': 8, '3000002012': 5, '3000002035': 3, '3000002054': 3, '3000002043': 1, '3000002000': 4, '3000002250': 12, '3000001747': 5, '3000001548': 4, '3000001946': 2, '3000001638': 2, '3000002119': 2, '3000002239': 3}, 'clusterCounts': {'910000529': 5, '910054539': 8, '910052419': 8, '910052115': 4, '910051416': 8, '910054538': 2, '910051415': 1, '910054432': 3, '910052114': 6, '910054566': 4, '910004219': 2, '910003921': 3}, 'amenityCounts': {'KITCHEN': 43, 'FPRKING': 31, 'AIRSHUTTL': 15, 'SPA': 22, 'KIDFRIEND': 17, 'FBRKFST': 54, 'HOTTUB': 24, 'SUSTAIN': 52, 'FAMFRIEND': 48, 'FITSPA': 53, 'NSMKFAC': 54, 'HANDFAC': 54, 'PETALLOW': 40, 'RESTRNT': 23, 'FINTRNT': 54, 'SPOOL': 40, 'HEALTHSVCS': 50}, 'starRatingCounts': {'2.5': 84, '3.5': 4, '2.0': 11, '3.0': 50}, 'brandIdCounts': {'22': 20, '12': 8, '67': 1, '72403': 2, '26': 2, '0': 
# ...

# %%
SJFalldata={}
SJFalldata = data['hotels']
SJFalldata
# Out:
# [{'hotelId': '190282004',
#   'name': 'Rodeway Inn',
#   'brand': 'Rodeway Inns',
#   'starRating': 3.0,
#   'location': {'address': {'addressLine1': '66 South Main Street',
#     'cityName': 'Milpitas',
#     'provinceCode': 'CA',
#     'countryName': 'United States',
#     'zip': '95035',
#     'isoCountryCode': 'US'},
#    'longitude': -121.90593,
#    'latitude': 37.42943,
#    'timeZone': 'America/Los_Angeles',
#    'neighborhoodId': '910000529',
#    'neighborhoodName': 'Milpitas',
#    'cityId': 3000002012,
#    'zoneId': '529'},
#   'thumbnailUrl': 'https://mobileimg.priceline.com/htlimg/190282/190282004/thumbnail-150-square.jpg',
#   'hotelFeatures': {'hotelAmenityCodes': ['FBRKFST',
#     'FINTRNT',
#     'FPRKING',
#     'HEALTHSVCS',
#     'FITSPA',
#     'PETALLOW',
#     'HANDFAC',
#     'NSMKFAC',
#     'SUSTAIN',
#     'FAMFRIEND']},
#   'overallGuestRating': 7.5,
#   'totalReviewCount': 121,
#   'proximity': 8.44490571558888,
# ...

# %%
SJFallprices=[]
for hotel in SJFalldata:
    SJFallprices.append(hotel["ratesSummary"])

# %%
print(SJprices)
# Out:
# [{'minPrice': '95.07', 'minCurrencyCode': 'USD', 'pclnId': 'ED6EF52C04E788BD1BE316689197E741688AA6B8E3DE254CAB2147699E3F85155F30614FA61FC451063D5A9B25B30ED6F4BA11844D4CAACF41F0978C897B20276995D6875B648B25', 'freeCancelableRateAvail': True, 'payWhenYouStayAvailable': True, 'gid': 2215, 'rateIdentifier': '241FD8F841B6D287FF56BA5F13D474AF23E71EB0109478D215B8B0DA6936F3D5A0A73482E84CD1466E5FC2CC18D2A46BF6E534FF6C773EA3108FEAB6953A42F6', 'ccNotRequiredAvailable': False, 'applePayRateAvailable': False}, {'minPrice': '99.25', 'minCurrencyCode': 'USD', 'minStrikePrice': '118.15', 'pclnId': '2D05BD569DE1198DA10AF073CD138440C393FD7CC145AF574DCF0272FA17A51204D5983AF7DF5F83EBDC542A70D2C5F9827DDB0B9BB4E255C97FE69D0CDF16E7DBF4A227004C506DE5BCDB657CAC703A', 'freeCancelableRateAvail': True, 'payWhenYouStayAvailable': True, 'roomLeft': 1, 'gid': 2273, 'rateIdentifier': '04D5983AF7DF5F83EBDC542A70D2C5F9827DDB0B9BB4E255C97FE69D0CDF16E7E1CF180FD46DB9F7F84DDCAF26D2ACAFCE007CEFBF28299E0EE9ADA90B47A7D5F9C6C
# ...

# %%
SJFallprice_df=pd.DataFrame(SJFallprices)
SJFallprice_df.head()
# Out:
#   minPrice minCurrencyCode                                             pclnId  \
# 0    95.07             USD  A84FDFF7ED0F201B1BE316689197E741688AA6B8E3DE25...
# 1    99.25             USD  EE26999231510FFBA10AF073CD138440C393FD7CC145AF...
# 2   107.00             USD  7E7EE20F94257BB3C7308D831C64FF110960C191805211...
# 3   108.12             USD  9EAF95EF7E8C52D334978BE56DA959C4C393FD7CC145AF...
# 4   115.00             USD  266C8041B3092A3F7CC0E1AB1AB940C713B696F33340DF...
#
#    freeCancelableRateAvail  payWhenYouStayAvailable   gid  \
# 0                     True                     True  2171
# 1                     True                     True  2701
# 2                    False                    False  3301
# 3                     True                     True  2511
# 4                    False                    False  3382
#
#                                       rateIdentifier  ccNotRequiredAvailable  \
# ...

# %%
SJFallprice_df.columns
# Out:
# Index(['minPrice', 'minCurrencyCode', 'pclnId', 'freeCancelableRateAvail',
#        'payWhenYouStayAvailable', 'gid', 'rateIdentifier',
#        'ccNotRequiredAvailable', 'applePayRateAvailable', 'minStrikePrice',
#        'roomLeft', 'programName', 'savingsPct', 'strikeThroughPrice',
#        'merchandisingFlag', 'minRateSavingsPercentage',
#        'minRateStrikeThroughPrice', 'minRatePromos'],
#       dtype='object')

# %%
columns_select=['minPrice', 'minStrikePrice', 'strikeThroughPrice',
                            'minRateSavingsPercentage', 'minRateStrikeThroughPrice']
SJFallprice_df_clean_fall=SJFallprice_df[columns_select]
SJFallprice_df_clean_fall.head()
# Out:
#   minPrice minStrikePrice strikeThroughPrice  minRateSavingsPercentage  \
# 0    95.07            NaN                NaN                       NaN
# 1    99.25         118.15             118.15                       NaN
# 2   107.00         139.00             139.00                      19.0
# 3   108.12         135.15             135.15                       NaN
# 4   115.00         148.40             148.40                      20.0
#
#   minRateStrikeThroughPrice
# 0                       NaN
# 1                       NaN
# 2                       132
# 3                       NaN
# 4                       143

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000001947","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 786, 'marketSize': 1300, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 54, 'cityCounts': {'3000002223': 1, '3000002201': 3, '3000001451': 8, '3000002389': 3, '3000001586': 2, '3000001695': 2, '3000002484': 2, '3000002473': 2, '3000001947': 10, '3000001813': 1, '3000001526': 6, '3000001758': 1, '3000001802': 2, '3000002449': 2, '3000001637': 1, '3000001911': 1, '3000001972': 3, '3000002027': 2, '3000002127': 2}, 'clusterCounts': {'910052434': 2, '910054502': 1, '910052436': 8, '910052338': 1, '910053134': 1, '910053135': 3, '910055037': 5, '910054883': 2, '910053246': 2, '910053247': 6, '910054882': 2, '910004041': 3, '910053111': 1, '910003218': 8, '910052380': 3, '910003203': 6}, 'amenityCounts': {'KITCHEN': 43, 'FPRKING': 20, 'AIRSHUTTL': 19, 'SPA': 22, 'KIDFRIEND': 26, 'FBRKFST': 54, 'HOTTUB': 28, 'SUSTAIN': 51, 'FAMFRIEND': 49, 'FITSPA': 53, 'NSMKFAC': 53, 'HANDFAC': 54, 'PETALLOW': 34, 'RESTRNT': 36, 'FINTRNT': 54, 'S
# ...

# %%
LAdata={}
LAdata = data['hotels']
LAdata
# Out:
# [{'hotelId': '43111',
#   'name': 'Best Western Plus South Bay Hotel',
#   'brand': 'Best Western',
#   'starRating': 3.0,
#   'location': {'address': {'addressLine1': '15000 Hawthorne Boulevard',
#     'cityName': 'Lawndale',
#     'provinceCode': 'CA',
#     'countryName': 'United States',
#     'zip': '90260',
#     'isoCountryCode': 'US'},
#    'longitude': -118.352362,
#    'latitude': 33.895339,
#    'timeZone': 'America/Los_Angeles',
#    'neighborhoodId': '910052436',
#    'neighborhoodName': 'Manhattan Beach - Hermosa Beach - Redondo Beach',
#    'cityId': 3000001911,
#    'zoneId': '52436'},
#   'thumbnailUrl': 'https://mobileimg.priceline.com/htlimg/43/43111/thumbnail-150-square.jpg',
#   'hotelFeatures': {'hotelAmenityCodes': ['FBRKFST',
#     'FINTRNT',
#     'FPRKING',
#     'HEALTHSVCS',
#     'SPOOL',
#     'FITSPA',
#     'SPA',
#     'HANDFAC',
#     'NSMKFAC',
#     'SUSTAIN',
#     'HOTTUB',
#     'FAMFRIEND']},
#   'overallGuestRating': 7.3,
# ...

# %%
LAprices=[]
for hotel in LAdata:
    LAprices.append(hotel["ratesSummary"])

# %%
LAprices_df=pd.DataFrame(LAprices)
LAprices_df.head()
# Out:
#   minPrice minCurrencyCode                                             pclnId  \
# 0   127.49             USD  6D46436BF748D0DC0C2449532C044D60C393FD7CC145AF...
# 1   134.00             USD  6BFFE4FCC87F02FB241373728880AF85C06661E41B2541...
# 2   135.15             USD  650F412F22976FBEF416188DD1F40A4EC393FD7CC145AF...
# 3   136.00             USD  AACA0215BF2A7CF87D9F66464CB8EDCF0960C191805211...
# 4   139.00             USD  7F0E0334B57BC3ACA42A9423504CB3200960C191805211...
#
#    freeCancelableRateAvail  payWhenYouStayAvailable  \
# 0                     True                     True
# 1                    False                    False
# 2                     True                     True
# 3                    False                    False
# 4                    False                    False
#
#                                        minRatePromos  roomLeft   gid  \
# 0  [{'type': 'DISCOUNT', 'title': 'Early Booking ...       2.0  3148
# ...

# %%
columns_select=['minPrice', 'minStrikePrice', 'strikeThroughPrice',
                            'minRateSavingsPercentage', 'minRateStrikeThroughPrice']
LAprice_df_clean_fall=SJprice_df[columns_select]
LAprice_df_clean_fall.head()
# Out:
#   minPrice minStrikePrice strikeThroughPrice  minRateSavingsPercentage  \
# 0    95.07            NaN                NaN                       NaN
# 1    99.25         118.15             118.15                       NaN
# 2   107.00         139.00             139.00                      19.0
# 3   108.12         135.15             135.15                       NaN
# 4   115.00         148.40             148.40                      20.0
#
#   minRateStrikeThroughPrice
# 0                       NaN
# 1                       NaN
# 2                       132
# 3                       NaN
# 4                       143

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000001438","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 59, 'marketSize': 767, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 76, 'cityCounts': {'3000002487': 2, '3000002288': 2, '3000002252': 2, '3000002097': 4, '3000090017': 2, '3000001828': 2, '3000001438': 23, '3000001945': 2, '3000001624': 1, '3000001844': 8, '3000001756': 5, '3000001429': 2, '3000002405': 3, '3000001743': 4, '3000001884': 2, '3000002269': 2, '3000001752': 2, '3000001896': 2, '3000002017': 4, '3000002226': 2}, 'clusterCounts': {'910052119': 4, '910052214': 6, '910052204': 2, '910052985': 13, '910052139': 2, '910052118': 8, '910052800': 7, '910054930': 7, '910052213': 2, '910052140': 2, '910052141': 2, '910054670': 2, '910052142': 1, '910052143': 8, '910003636': 4, '910000347': 2, '910054390': 3}, 'amenityCounts': {'KITCHEN': 61, 'FPRKING': 30, 'AIRSHUTTL': 27, 'SPA': 45, 'KIDFRIEND': 36, 'FBRKFST': 76, 'HOTTUB': 61, 'SUSTAIN': 53, 'FAMFRIEND': 72, 'FITSPA': 72, 'NSMKFAC': 74, 'HANDFAC': 76, 'PETALLOW': 55, 
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002228","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 26, 'marketSize': 227, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 33, 'cityCounts': {'3000002224': 9, '3000002188': 4, '3000002451': 2, '3000001728': 2, '3000001646': 2, '3000002219': 2, '3000002228': 12}, 'clusterCounts': {'910003101': 11, '910051908': 2, '910004142': 3, '910053022': 2, '910053023': 2, '910051910': 2, '910002454': 6, '910050923': 2, '910000453': 3}, 'amenityCounts': {'KITCHEN': 23, 'FPRKING': 21, 'AIRSHUTTL': 6, 'SPA': 13, 'KIDFRIEND': 7, 'FBRKFST': 33, 'HOTTUB': 17, 'SUSTAIN': 30, 'FAMFRIEND': 29, 'FITSPA': 32, 'NSMKFAC': 33, 'HANDFAC': 33, 'PETALLOW': 25, 'RESTRNT': 21, 'FINTRNT': 33, 'SPOOL': 29, 'HEALTHSVCS': 27}, 'starRatingCounts': {'2.5': 91, '2.0': 15, '3.0': 33}, 'brandIdCounts': {'22': 10, '1': 2, '12': 5, '3': 1, '28302': 4, '116': 3, '437304': 2, '467304': 4, '14702': 2}, 'propertyTypeCounts': {'204': 33}, 'propertyType': [{'typeId': '204', 'typeTitle': 'Hotels', 'count': 33}], 'dealTypeCou
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002117","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 12, 'marketSize': 1165, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 15, 'cityCounts': {'3000002117': 3, '3000001887': 6, '3000001576': 2, '3000002116': 4}, 'clusterCounts': {'910001074': 3, '910054684': 2, '910050206': 2, '910054669': 8}, 'amenityCounts': {'KITCHEN': 10, 'FPRKING': 13, 'AIRSHUTTL': 2, 'SPA': 6, 'KIDFRIEND': 2, 'FBRKFST': 15, 'HOTTUB': 11, 'SUSTAIN': 15, 'FAMFRIEND': 14, 'FITSPA': 14, 'NSMKFAC': 15, 'HANDFAC': 15, 'PETALLOW': 13, 'ADULTONLY': 1, 'RESTRNT': 11, 'FINTRNT': 15, 'SPOOL': 15, 'HEALTHSVCS': 13}, 'starRatingCounts': {'2.5': 31, '3.5': 3, '2.0': 4, '3.0': 12}, 'brandIdCounts': {'22': 4, '0': 1, '12': 6, '1': 2, '7': 2}, 'propertyTypeCounts': {'204': 15}, 'propertyType': [{'typeId': '204', 'typeTitle': 'Hotels', 'count': 15}], 'dealTypeCounts': {'GEO_DEALS': 1, 'EXPRESS_DEAL': 7}, 'minFilterPrice': '0.00', 'maxFilterPrice': '500.0', 'maxFilterPricePerStay': '500.0'}, 'cityInfo': {'cityId': 3000002
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002028","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 167, 'marketSize': 219, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 5, 'cityCounts': {'3000001977': 2, '3000002231': 1, '3000002028': 2}, 'clusterCounts': {'910051359': 2, '910054717': 2, '910051663': 1}, 'amenityCounts': {'KITCHEN': 3, 'FPRKING': 2, 'SPA': 2, 'FBRKFST': 5, 'HOTTUB': 4, 'SUSTAIN': 5, 'FAMFRIEND': 3, 'FITSPA': 3, 'NSMKFAC': 5, 'HANDFAC': 5, 'PETALLOW': 1, 'RESTRNT': 4, 'FINTRNT': 5, 'SPOOL': 1, 'HEALTHSVCS': 5}, 'starRatingCounts': {'2.5': 34, '3.5': 2, '2.0': 3, '3.0': 3}, 'brandIdCounts': {'0': 2, '22': 1, '1': 1, '116': 1}, 'propertyTypeCounts': {'204': 5}, 'propertyType': [{'typeId': '204', 'typeTitle': 'Hotels', 'count': 5}], 'dealTypeCounts': {'MOBILE_DEALS': 1, 'EXPRESS_DEAL': 1}, 'minFilterPrice': '0.00', 'maxFilterPrice': '500.0', 'maxFilterPricePerStay': '500.0'}, 'cityInfo': {'cityId': 3000002028, 'cityName': 'Monterey', 'stateCode': 'CA', 'stateName': 'California', 'countryCode': 'US', 'countr
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000001750","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 85, 'marketSize': 69, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 16, 'cityCounts': {'3000001750': 12, '3000001604': 4}, 'clusterCounts': {'910051175': 2, '910054728': 2, '910051675': 4, '910051177': 8}, 'amenityCounts': {'KITCHEN': 10, 'FPRKING': 9, 'AIRSHUTTL': 8, 'SPA': 6, 'KIDFRIEND': 3, 'FBRKFST': 16, 'HOTTUB': 14, 'SUSTAIN': 14, 'FAMFRIEND': 14, 'FITSPA': 16, 'NSMKFAC': 16, 'HANDFAC': 16, 'PETALLOW': 12, 'RESTRNT': 6, 'FINTRNT': 16, 'SPOOL': 16, 'HEALTHSVCS': 14}, 'starRatingCounts': {'2.5': 39, '2.0': 1, '3.0': 16}, 'brandIdCounts': {'12': 4, '67': 2, '1': 1, '72403': 2, '26': 1, '116': 2, '467304': 2, '20': 2}, 'propertyTypeCounts': {'204': 16}, 'propertyType': [{'typeId': '204', 'typeTitle': 'Hotels', 'count': 16}], 'dealTypeCounts': {'MOBILE_DEALS': 3, 'EXPRESS_DEAL': 7}, 'minFilterPrice': '0.00', 'maxFilterPrice': '500.0', 'maxFilterPricePerStay': '500.0'}, 'cityInfo': {'cityId': 3000001750, 'cityName': 'Fresn
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000001942","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 8, 'marketSize': 103, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 10, 'cityCounts': {'3000001942': 10}, 'clusterCounts': {'910000892': 2, '910052544': 2, '910000891': 6}, 'amenityCounts': {'KITCHEN': 10, 'AIRSHUTTL': 4, 'SPA': 4, 'KIDFRIEND': 4, 'FBRKFST': 10, 'HOTTUB': 8, 'SUSTAIN': 10, 'FAMFRIEND': 8, 'FITSPA': 10, 'NSMKFAC': 10, 'HANDFAC': 10, 'PETALLOW': 8, 'RESTRNT': 8, 'FINTRNT': 10, 'SPOOL': 10, 'HEALTHSVCS': 10}, 'starRatingCounts': {'2.5': 6, '2.0': 3, '3.0': 10}, 'brandIdCounts': {'22': 4, '12': 2, '1': 2, '28302': 2}, 'propertyTypeCounts': {'204': 10}, 'propertyType': [{'typeId': '204', 'typeTitle': 'Hotels', 'count': 10}], 'dealTypeCounts': {'MOBILE_DEALS': 1, 'EXPRESS_DEAL': 5}, 'minFilterPrice': '0.00', 'maxFilterPrice': '500.0', 'maxFilterPricePerStay': '500.0'}, 'cityInfo': {'cityId': 3000001942, 'cityName': 'Long Beach', 'stateCode': 'CA', 'stateName': 'California', 'countryCode': 'US', 'countryName': 'U
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002277","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 786, 'marketSize': 1300, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 54, 'cityCounts': {'3000002201': 3, '3000002223': 1, '3000001451': 8, '3000002389': 3, '3000001586': 2, '3000001695': 2, '3000002473': 2, '3000002484': 2, '3000001947': 10, '3000001813': 1, '3000001802': 2, '3000001526': 6, '3000001758': 1, '3000002449': 2, '3000001637': 1, '3000001911': 1, '3000001972': 3, '3000002027': 2, '3000002127': 2}, 'clusterCounts': {'910052434': 2, '910054502': 1, '910052436': 8, '910052338': 1, '910053134': 1, '910055037': 5, '910053135': 3, '910054883': 2, '910053246': 2, '910053247': 6, '910054882': 2, '910004041': 3, '910053111': 1, '910003218': 8, '910052380': 3, '910003203': 6}, 'amenityCounts': {'KITCHEN': 43, 'FPRKING': 20, 'AIRSHUTTL': 19, 'SPA': 22, 'KIDFRIEND': 26, 'FBRKFST': 54, 'HOTTUB': 28, 'SUSTAIN': 51, 'FAMFRIEND': 49, 'FITSPA': 53, 'NSMKFAC': 53, 'HANDFAC': 54, 'PETALLOW': 34, 'RESTRNT': 36, 'FINTRNT': 54, 'S
# ...

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/search"

querystring = {"date_checkout":"2023-10-19","sort_order":"PRICE","location_id":"3000002049","date_checkin":"2023-10-18","amenities_ids":"FINTRNT,FBRKFST","rooms_number":"1","star_rating_ids":"3.0,3.5,4.0,4.5,5.0"}

headers = {
	"X-RapidAPI-Key": "3e6b744580msh4923cc9e6404566p18d83fjsnf66d6bfce325",
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()
print(data)
# Out:
# {'offset': 0, 'pageSize': 100, 'totalSize': 266, 'marketSize': 531, 'sortType': 'PRICE', 'tripFilterSummary': {'totalSizeFiltered': 16, 'cityCounts': {'3000002418': 1, '3000001715': 6, '3000002229': 1, '3000001765': 1, '3000002415': 1, '3000002049': 4, '3000002324': 2}, 'clusterCounts': {'910052410': 4, '910051412': 6, '910054680': 1, '910051411': 1, '910003726': 3}, 'amenityCounts': {'KITCHEN': 8, 'FPRKING': 11, 'AIRSHUTTL': 6, 'SPA': 7, 'KIDFRIEND': 6, 'FBRKFST': 16, 'HOTTUB': 13, 'SUSTAIN': 12, 'FAMFRIEND': 16, 'FITSPA': 12, 'NSMKFAC': 16, 'HANDFAC': 16, 'PETALLOW': 14, 'ADULTONLY': 1, 'RESTRNT': 7, 'FINTRNT': 16, 'SPOOL': 16, 'HEALTHSVCS': 13}, 'starRatingCounts': {'2.5': 57, '4.5': 1, '2.0': 4, '3.0': 14, '4.0': 1}, 'brandIdCounts': {'0': 3, '22': 1, '67': 2, '12': 2, '483304': 1, '1': 2, '28302': 2, '115': 1, '9': 2}, 'propertyTypeCounts': {'218': 1, '208': 1, '204': 14}, 'propertyType': [{'typeId': '204', 'typeTitle': 'Hotels', 'count': 14}, {'typeId': '208', 'typeTitle': 'Bed
# ...
