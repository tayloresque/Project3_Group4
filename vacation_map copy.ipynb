# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import os

# Import the Priceline API key
from api_keys import priceline_api_key

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"HOTEL"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Houston, TX",
#         "id": "3000021312",
#         "cityID": "3000021312",
#         "type": "CITY",
#         "lat": 29.7631,
#         "lon": -95.3631,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 203149.08,
#         "radius": 39.6,
#         "rank": 66.03496,
#         "rank2": 93.02373504638672,
#         "globalScore": 100.0,
#         "globalScoreReducedCityBoost": 58.286484,
#         "globalScoreWOHotelCountNormalize": 46.649864,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Las Vegas, NV",
#         "id": "3000015284",
#         "cityID": "3000015284",
#         "type": "CITY",
#         "lat": 36.175,
#         "lon": -115.136,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 203129.36,
#         "radius": 28.0,
#         "rank": 100.0,
#         "rank2": 100.0,
#         "globalScore": 99.95409,
#         "globalScoreReducedCityBoost": 100.0,
#         "globalScoreWOHotelCountNormalize": 100.0,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Orlando, FL",
#         "id": "3000003349",
#         "cityID": "3000003349",
#         "type": "CITY",
#         "lat": 28.5381,
#         "lon": -81.3794,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Orlando",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 202687.66,
#         "radius": 33.7,
#         "rank": 82.260895,
#         "rank2": 97.8792495727539,
#         "globalScore": 98.93259,
#         "globalScoreReducedCityBoost": 65.36813,
#         "globalScoreWOHotelCountNormalize": 56.468636,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Orlando",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "New York, NY",
#         "id": "3000016152",
#         "cityID": "3000016152",
#         "type": "CITY",
#         "lat": 40.759378,
#         "lon": -73.985131,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "New York",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 202481.8,
#         "radius": 15.9,
#         "rank": 88.94353,
#         "rank2": 96.2424545288086,
#         "globalScore": 98.45999,
#         "globalScoreReducedCityBoost": 52.378162,
#         "globalScoreWOHotelCountNormalize": 46.737076,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "New York",
#         "displayLine2": "New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "San Antonio, TX",
#         "id": "3000021763",
#         "cityID": "3000021763",
#         "type": "CITY",
#         "lat": 29.4239,
#         "lon": -98.4933,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Antonio",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 201948.83,
#         "radius": 38.4,
#         "rank": 62.74786,
#         "rank2": 92.44367218017578,
#         "globalScore": 97.246864,
#         "globalScoreReducedCityBoost": 49.077602,
#         "globalScoreWOHotelCountNormalize": 40.708843,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "San Antonio",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Atlanta, GA",
#         "id": "3000003496",
#         "cityID": "3000003496",
#         "type": "CITY",
#         "lat": 33.7489,
#         "lon": -84.3881,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Atlanta",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 201878.6,
#         "radius": 37.0,
#         "rank": 71.75888,
#         "rank2": 93.99879455566406,
#         "globalScore": 97.08815,
#         "globalScoreReducedCityBoost": 53.231205,
#         "globalScoreWOHotelCountNormalize": 44.350124,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Atlanta",
#         "displayLine2": "Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ellington Airport (EFD) , TX",
#         "id": "EFD",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.649992940224973,
#         "lon": -95.283339696492,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 193025.95,
#         "radius": 39.6,
#         "rank": 12.332901,
#         "rank2": 43.747379302978516,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.074444,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - Ellington Airport (EFD)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "William P. Hobby Airport (HOU) , TX",
#         "id": "HOU",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.645180094745875,
#         "lon": -95.27864144257192,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 193025.95,
#         "radius": 39.6,
#         "rank": 33.20637,
#         "rank2": 76.55439758300781,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.199505,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - William P. Hobby Airport (HOU)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "George Bush Intercontinental Airport (IAH) , TX",
#         "id": "IAH",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.98672023642336,
#         "lon": -95.34223975783146,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 193025.95,
#         "radius": 39.6,
#         "rank": 40.247612,
#         "rank2": 79.82408905029297,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.292503,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - George Bush Intercontinental Airport (IAH)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Harry Reid Intl Airport (LAS) , NV",
#         "id": "LAS",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 36.08167337368651,
#         "lon": -115.15489113033726,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 193008.44,
#         "radius": 28.0,
#         "rank": 35.791367,
#         "rank2": 80.38639831542969,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 65.631096,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - Harry Reid Intl Airport (LAS)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "North Las Vegas Airport (VGT) , NV",
#         "id": "VGT",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 36.183316086542725,
#         "lon": -115.13329062146084,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 193008.44,
#         "radius": 28.0,
#         "rank": 20.259972,
#         "rank2": 64.59667205810547,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 64.87798,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - North Las Vegas Airport (VGT)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Henderson Executive Airport (HSH) , NV",
#         "id": "HSH",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 35.97441567443802,
#         "lon": -115.13541056530282,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 193008.44,
#         "radius": 28.0,
#         "rank": 0.5,
#         "rank2": 55.4843864440918,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 64.84516,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - Henderson Executive Airport (HSH)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Military Academy - West Point, NY",
#         "id": "63670",
#         "cityID": "3000016595",
#         "type": "POI",
#         "lat": 41.377613,
#         "lon": -73.963524,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "West Point",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 164305.83,
#         "radius": 50.0,
#         "rank": 16.673111,
#         "rank2": 5.93569278717041,
#         "globalScore": 32.28524,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.067547,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 13,
#         "poiCategoryName": "Monuments and Landmarks",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Military Academy",
#         "displayLine2": "West Point, New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Sheep Experiment Station - Lima, MT",
#         "id": "183853",
#         "cityID": "3000012642",
#         "type": "POI",
#         "lat": 44.56659,
#         "lon": -111.58413,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lima",
#         "stateCode": "MT",
#         "provinceName": "Montana",
#         "score": 164302.53,
#         "radius": 25.0,
#         "rank": 12.555779,
#         "rank2": 5.9291205406188965,
#         "globalScore": 32.28271,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064873,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 26,
#         "poiCategoryName": "Other",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Sheep Experiment Station",
#         "displayLine2": "Lima, Montana",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Department of the Interior Museum - Washington, DC",
#         "id": "110273",
#         "cityID": "3000003032",
#         "type": "POI",
#         "lat": 38.88233,
#         "lon": -77.04275,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Washington",
#         "stateCode": "DC",
#         "provinceName": "District Of Columbia",
#         "score": 164302.53,
#         "radius": 19.9,
#         "rank": 12.555779,
#         "rank2": 5.9291205406188965,
#         "globalScore": 32.28271,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064884,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 14,
#         "poiCategoryName": "Museums and Art Galleries",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Department of the Interior Museum",
#         "displayLine2": "Washington, District Of Columbia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Coast Guard Academy - New London, CT",
#         "id": "99596806",
#         "cityID": "3000002921",
#         "type": "POI",
#         "lat": 41.370531,
#         "lon": -72.103396,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "New London",
#         "stateCode": "CT",
#         "provinceName": "Connecticut",
#         "score": 164302.1,
#         "radius": 19.1,
#         "rank": 12.106464,
#         "rank2": 5.928276538848877,
#         "globalScore": 32.282387,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064583,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 7,
#         "poiCategoryName": "Camping and Outdoors",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Coast Guard Academy",
#         "displayLine2": "New London, Connecticut",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Army Medical Department Museum - San Antonio, TX",
#         "id": "132381",
#         "cityID": "3000021763",
#         "type": "POI",
#         "lat": 29.46134,
#         "lon": -98.43807,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Antonio",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 164302.02,
#         "radius": 38.4,
#         "rank": 12.017747,
#         "rank2": 5.928106307983398,
#         "globalScore": 32.282322,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064545,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 14,
#         "poiCategoryName": "Museums and Art Galleries",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Army Medical Department Museum",
#         "displayLine2": "San Antonio, Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Air Force Academy, Cadet Area - Usaf Academy, CO",
#         "id": "99478306",
#         "cityID": "3000002781",
#         "type": "POI",
#         "lat": 39.008333,
#         "lon": -104.890417,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Usaf Academy",
#         "stateCode": "CO",
#         "provinceName": "Colorado",
#         "score": 164301.84,
#         "radius": 28.4,
#         "rank": 11.836448,
#         "rank2": 5.9277544021606445,
#         "globalScore": 32.282185,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064396,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 9,
#         "poiCategoryName": "Colleges and Universities",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Air Force Academy, Cadet Area",
#         "displayLine2": "Usaf Academy, Colorado",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Heart Of Highlands 3br Loft - Louisville, KY",
#         "id": "138799303",
#         "cityID": "3000007866",
#         "type": "HOTEL",
#         "lat": 38.2331,
#         "lon": -85.7117,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Louisville",
#         "stateCode": "KY",
#         "provinceName": "Kentucky",
#         "score": 152216.48,
#         "radius": 30.0,
#         "rank": 0.5,
#         "rank2": 5.8549346923828125,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "US",
#         "address": "1864 EDGELAND AVENUE LOUISVILLE KY 40204 UNITED STATES",
#         "zip": "40204",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Heart Of Highlands 3br Loft",
#         "displayLine2": "Louisville, Kentucky",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Parker's Motel - Lincoln, NH",
#         "id": "5679604",
#         "cityID": "3000014398",
#         "type": "HOTEL",
#         "lat": 44.08985255,
#         "lon": -71.68328851,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lincoln",
#         "stateCode": "NH",
#         "provinceName": "New Hampshire",
#         "score": 152216.48,
#         "radius": 39.4,
#         "rank": 11.862453,
#         "rank2": 47.121917724609375,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.070166,
#         "country": "US",
#         "address": "750 UNITED STATES ROUTE 3 ",
#         "zip": "03251",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Parker's Motel",
#         "displayLine2": "Lincoln, New Hampshire",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Holiday Inn Express Statesboro - Statesboro, GA",
#         "id": "53753",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.43677902,
#         "lon": -81.78549957,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151853.2,
#         "radius": 25.0,
#         "rank": 11.810301,
#         "rank2": 56.01250457763672,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.504097,
#         "country": "US",
#         "address": "427 S MAIN STREET",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Holiday Inn Express Statesboro",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Eagles Nest Inn - Statesboro, GA",
#         "id": "4556805",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.40799332,
#         "lon": -81.782547,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151853.2,
#         "radius": 25.0,
#         "rank": 11.810301,
#         "rank2": 5.927702903747559,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.39699,
#         "country": "US",
#         "address": "225 LANIER DRIVE",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Eagles Nest Inn",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Red Roof Inn & Suites Statesboro - University - Statesboro, GA",
#         "id": "2544205",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.44120789,
#         "lon": -81.78367615,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151853.2,
#         "radius": 25.0,
#         "rank": 11.810301,
#         "rank2": 17.92148208618164,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.195726,
#         "country": "US",
#         "address": "316 S MAIN STREET",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Red Roof Inn & Suites Statesboro - University",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Days Inn BY Wyndham Statesboro - Statesboro, GA",
#         "id": "54357",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.43232727,
#         "lon": -81.77883148,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151853.2,
#         "radius": 25.0,
#         "rank": 11.812754,
#         "rank2": 61.35292053222656,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.638893,
#         "country": "US",
#         "address": "616 FAIR ROAD",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Days Inn BY Wyndham Statesboro",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

hotel_data = pd.DataFrame(dictionary_data)

hotel_data.head()
# Out:
#           itemName          id      cityID  type        lat         lon  \
# 0      Houston, TX  3000021312  3000021312  CITY  29.763100  -95.363100
# 1    Las Vegas, NV  3000015284  3000015284  CITY  36.175000 -115.136000
# 2      Orlando, FL  3000003349  3000003349  CITY  28.538100  -81.379400
# 3     New York, NY  3000016152  3000016152  CITY  40.759378  -73.985131
# 4  San Antonio, TX  3000021763  3000021763  CITY  29.423900  -98.493300
#
#    proximity savedTravelStartDate savedTravelEndDate     cityName  ...  \
# 0        0.0                 None               None      Houston  ...
# 1        0.0                 None               None    Las Vegas  ...
# 2        0.0                 None               None      Orlando  ...
# 3        0.0                 None               None     New York  ...
# 4        0.0                 None               None  San Antonio  ...
#
#   poiCategoryTypeId poiCategoryName  poiID  seType  gmtOffset        entered  \
# 0                 0            None   None    None       -5.0  united states
# 1                 0            None   None    None       -7.0  united states
# 2                 0            None   None    None       -4.0  united states
# 3                 0            None   None    None       -4.0  united states
# 4                 0            None   None    None       -5.0  united states
#
#    highlightedName  displayLine1  displayLine2 fromSavedSearch
# 0             None       Houston         Texas           False
# 1             None     Las Vegas        Nevada           False
# 2             None       Orlando       Florida           False
# 3             None      New York      New York           False
# 4             None   San Antonio         Texas           False
#
# [5 rows x 34 columns]

# %%
hotel_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
hotel_data['city'] = hotel_data['itemName'].str.split(',').str[0]
hotel_data['state'] = hotel_data['itemName'].str.split(',').str[1]

column_to_select = ['cityID',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country', 
                    ]

hotel_data_select = hotel_data[column_to_select]

hotel_data_select.head()
# Out:
#         cityID                                               city  \
# 0   3000021312                                            Houston
# 1   3000015284                                          Las Vegas
# 2   3000003349                                            Orlando
# 3   3000016152                                           New York
# 4   3000021763                                        San Antonio
# 5   3000003496                                            Atlanta
# 6   3000021312                           Ellington Airport (EFD)
# 7   3000021312                    William P. Hobby Airport (HOU)
# 8   3000021312        George Bush Intercontinental Airport (IAH)
# 9   3000015284                     Harry Reid Intl Airport (LAS)
# 10  3000015284                     North Las Vegas Airport (VGT)
# 11  3000015284                 Henderson Executive Airport (HSH)
# 12  3000016595        United States Military Academy - West Point
# 13  3000012642      United States Sheep Experiment Station - Lima
# 14  3000003032  United States Department of the Interior Museu...
# 15  3000002921     United States Coast Guard Academy - New London
# 16  3000021763  United States Army Medical Department Museum -...
# 17  3000002781                    United States Air Force Academy
# 18  3000007866           Heart Of Highlands 3br Loft - Louisville
# 19  3000014398                           Parker's Motel - Lincoln
#
#                          state        lat         lon      score        rank  \
# 0                           TX  29.763100  -95.363100  203149.08   66.034960
# 1                           NV  36.175000 -115.136000  203129.36  100.000000
# 2                           FL  28.538100  -81.379400  202687.66   82.260895
# 3                           NY  40.759378  -73.985131  202481.80   88.943530
# 4                           TX  29.423900  -98.493300  201948.83   62.747860
# 5                           GA  33.748900  -84.388100  201878.60   71.758880
# 6                           TX  29.649993  -95.283340  193025.95   12.332901
# 7                           TX  29.645180  -95.278641  193025.95   33.206370
# 8                           TX  29.986720  -95.342240  193025.95   40.247612
# 9                           NV  36.081673 -115.154891  193008.44   35.791367
# 10                          NV  36.183316 -115.133291  193008.44   20.259972
# 11                          NV  35.974416 -115.135411  193008.44    0.500000
# 12                          NY  41.377613  -73.963524  164305.83   16.673111
# 13                          MT  44.566590 -111.584130  164302.53   12.555779
# 14                          DC  38.882330  -77.042750  164302.53   12.555779
# 15                          CT  41.370531  -72.103396  164302.10   12.106464
# 16                          TX  29.461340  -98.438070  164302.02   12.017747
# 17   Cadet Area - Usaf Academy  39.008333 -104.890417  164301.84   11.836448
# 18                          KY  38.233100  -85.711700  152216.48    0.500000
# 19                          NH  44.089853  -71.683289  152216.48   11.862453
#
#          rank2  globalScore country    countryName countryCode  \
# 0    93.023735   100.000000      US  UNITED STATES          US
# 1   100.000000    99.954090      US  UNITED STATES          US
# 2    97.879250    98.932590      US  UNITED STATES          US
# 3    96.242455    98.459990      US  UNITED STATES          US
# 4    92.443672    97.246864      US  UNITED STATES          US
# 5    93.998795    97.088150      US  UNITED STATES          US
# 6    43.747379    79.000000      US  UNITED STATES          US
# 7    76.554398    79.000000      US  UNITED STATES          US
# 8    79.824089    79.000000      US  UNITED STATES          US
# 9    80.386398    78.967730      US  UNITED STATES          US
# 10   64.596672    78.967730      US  UNITED STATES          US
# 11   55.484386    78.967730      US  UNITED STATES          US
# 12    5.935693    32.285240      US  UNITED STATES          US
# 13    5.929121    32.282710      US  UNITED STATES          US
# 14    5.929121    32.282710      US  UNITED STATES          US
# 15    5.928277    32.282387      US  UNITED STATES          US
# 16    5.928106    32.282322      US  UNITED STATES          US
# 17    5.927754    32.282185      US  UNITED STATES          US
# 18    5.854935    30.000000      US  UNITED STATES          US
# 19   47.121918    30.000000      US  UNITED STATES          US
#
#                                          displayLine1  \
# 0                                             Houston
# 1                                           Las Vegas
# 2                                             Orlando
# 3                                            New York
# 4                                         San Antonio
# 5                                             Atlanta
# 6                   Houston - Ellington Airport (EFD)
# 7            Houston - William P. Hobby Airport (HOU)
# 8   Houston - George Bush Intercontinental Airport...
# 9           Las Vegas - Harry Reid Intl Airport (LAS)
# 10          Las Vegas - North Las Vegas Airport (VGT)
# 11      Las Vegas - Henderson Executive Airport (HSH)
# 12                     United States Military Academy
# 13             United States Sheep Experiment Station
# 14    United States Department of the Interior Museum
# 15                  United States Coast Guard Academy
# 16       United States Army Medical Department Museum
# 17        United States Air Force Academy, Cadet Area
# 18                        Heart Of Highlands 3br Loft
# 19                                     Parker's Motel
#
#                         displayLine2
# 0                              Texas
# 1                             Nevada
# 2                            Florida
# 3                           New York
# 4                              Texas
# 5                            Georgia
# 6                              Texas
# 7                              Texas
# 8                              Texas
# 9                             Nevada
# 10                            Nevada
# 11                            Nevada
# 12              West Point, New York
# 13                     Lima, Montana
# 14  Washington, District Of Columbia
# 15           New London, Connecticut
# 16                San Antonio, Texas
# 17            Usaf Academy, Colorado
# 18              Louisville, Kentucky
# 19            Lincoln, New Hampshire

# %%
hotel_data_select.dtypes
# Out:
# cityID           object
# city             object
# state            object
# lat             float64
# lon             float64
# score           float64
# rank            float64
# rank2           float64
# globalScore     float64
# country          object
# countryName      object
# countryCode      object
# displayLine1     object
# displayLine2     object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# cityID          0
# city            0
# state           0
# lat             0
# lon             0
# score           0
# rank            0
# rank2           0
# globalScore     0
# country         0
# countryName     0
# countryCode     0
# displayLine1    0
# displayLine2    0
# dtype: int64

# %%
# # Create a folder named "data" if it doesn't exist
# if not os.path.exists("data"):
#     os.mkdir("data")

# # Save DataFrame to a CSV file inside the "data" folder
# file_path = os.path.join("data", "hotel.csv")
# hotel_data_clean.to_csv(file_path, index=False)

# print("DataFrame saved to 'data/hotel.csv' file.")

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"AIRPORT"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Houston, TX",
#         "id": "3000021312",
#         "cityID": "3000021312",
#         "type": "CITY",
#         "lat": 29.7631,
#         "lon": -95.3631,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 203129.89,
#         "radius": 39.6,
#         "rank": 66.03496,
#         "rank2": 93.02373504638672,
#         "globalScore": 100.0,
#         "globalScoreReducedCityBoost": 58.286484,
#         "globalScoreWOHotelCountNormalize": 46.649864,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Las Vegas, NV",
#         "id": "3000015284",
#         "cityID": "3000015284",
#         "type": "CITY",
#         "lat": 36.175,
#         "lon": -115.136,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 203110.17,
#         "radius": 28.0,
#         "rank": 100.0,
#         "rank2": 100.0,
#         "globalScore": 99.95409,
#         "globalScoreReducedCityBoost": 100.0,
#         "globalScoreWOHotelCountNormalize": 100.0,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Orlando, FL",
#         "id": "3000003349",
#         "cityID": "3000003349",
#         "type": "CITY",
#         "lat": 28.5381,
#         "lon": -81.3794,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Orlando",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 202668.47,
#         "radius": 33.7,
#         "rank": 82.260895,
#         "rank2": 97.8792495727539,
#         "globalScore": 98.93259,
#         "globalScoreReducedCityBoost": 65.36813,
#         "globalScoreWOHotelCountNormalize": 56.468636,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Orlando",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "New York, NY",
#         "id": "3000016152",
#         "cityID": "3000016152",
#         "type": "CITY",
#         "lat": 40.759378,
#         "lon": -73.985131,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "New York",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 202462.61,
#         "radius": 15.9,
#         "rank": 88.94353,
#         "rank2": 96.2424545288086,
#         "globalScore": 98.45999,
#         "globalScoreReducedCityBoost": 52.378162,
#         "globalScoreWOHotelCountNormalize": 46.737076,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "New York",
#         "displayLine2": "New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "San Antonio, TX",
#         "id": "3000021763",
#         "cityID": "3000021763",
#         "type": "CITY",
#         "lat": 29.4239,
#         "lon": -98.4933,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Antonio",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 201929.64,
#         "radius": 38.4,
#         "rank": 62.74786,
#         "rank2": 92.44367218017578,
#         "globalScore": 97.246864,
#         "globalScoreReducedCityBoost": 49.077602,
#         "globalScoreWOHotelCountNormalize": 40.708843,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "San Antonio",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Atlanta, GA",
#         "id": "3000003496",
#         "cityID": "3000003496",
#         "type": "CITY",
#         "lat": 33.7489,
#         "lon": -84.3881,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Atlanta",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 201859.4,
#         "radius": 37.0,
#         "rank": 71.75888,
#         "rank2": 93.99879455566406,
#         "globalScore": 97.08815,
#         "globalScoreReducedCityBoost": 53.231205,
#         "globalScoreWOHotelCountNormalize": 44.350124,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Atlanta",
#         "displayLine2": "Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ellington Airport (EFD) , TX",
#         "id": "EFD",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.649992940224973,
#         "lon": -95.283339696492,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 193006.77,
#         "radius": 39.6,
#         "rank": 12.332901,
#         "rank2": 43.747379302978516,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.074444,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - Ellington Airport (EFD)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "William P. Hobby Airport (HOU) , TX",
#         "id": "HOU",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.645180094745875,
#         "lon": -95.27864144257192,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 193006.77,
#         "radius": 39.6,
#         "rank": 33.20637,
#         "rank2": 76.55439758300781,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.199505,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - William P. Hobby Airport (HOU)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "George Bush Intercontinental Airport (IAH) , TX",
#         "id": "IAH",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.98672023642336,
#         "lon": -95.34223975783146,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 193006.77,
#         "radius": 39.6,
#         "rank": 40.247612,
#         "rank2": 79.82408905029297,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.292503,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - George Bush Intercontinental Airport (IAH)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Harry Reid Intl Airport (LAS) , NV",
#         "id": "LAS",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 36.08167337368651,
#         "lon": -115.15489113033726,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 192989.25,
#         "radius": 28.0,
#         "rank": 35.791367,
#         "rank2": 80.38639831542969,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 65.631096,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - Harry Reid Intl Airport (LAS)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "North Las Vegas Airport (VGT) , NV",
#         "id": "VGT",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 36.183316086542725,
#         "lon": -115.13329062146084,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 192989.25,
#         "radius": 28.0,
#         "rank": 20.259972,
#         "rank2": 64.59667205810547,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 64.87798,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - North Las Vegas Airport (VGT)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Henderson Executive Airport (HSH) , NV",
#         "id": "HSH",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 35.97441567443802,
#         "lon": -115.13541056530282,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 192989.25,
#         "radius": 28.0,
#         "rank": 0.5,
#         "rank2": 55.4843864440918,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 64.84516,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - Henderson Executive Airport (HSH)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Military Academy - West Point, NY",
#         "id": "63670",
#         "cityID": "3000016595",
#         "type": "POI",
#         "lat": 41.377613,
#         "lon": -73.963524,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "West Point",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 164202.56,
#         "radius": 50.0,
#         "rank": 16.673111,
#         "rank2": 5.93569278717041,
#         "globalScore": 32.28524,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.067547,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 13,
#         "poiCategoryName": "Monuments and Landmarks",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Military Academy",
#         "displayLine2": "West Point, New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Sheep Experiment Station - Lima, MT",
#         "id": "183853",
#         "cityID": "3000012642",
#         "type": "POI",
#         "lat": 44.56659,
#         "lon": -111.58413,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lima",
#         "stateCode": "MT",
#         "provinceName": "Montana",
#         "score": 164199.27,
#         "radius": 25.0,
#         "rank": 12.555779,
#         "rank2": 5.9291205406188965,
#         "globalScore": 32.28271,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064873,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 26,
#         "poiCategoryName": "Other",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Sheep Experiment Station",
#         "displayLine2": "Lima, Montana",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Department of the Interior Museum - Washington, DC",
#         "id": "110273",
#         "cityID": "3000003032",
#         "type": "POI",
#         "lat": 38.88233,
#         "lon": -77.04275,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Washington",
#         "stateCode": "DC",
#         "provinceName": "District Of Columbia",
#         "score": 164199.27,
#         "radius": 19.9,
#         "rank": 12.555779,
#         "rank2": 5.9291205406188965,
#         "globalScore": 32.28271,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064884,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 14,
#         "poiCategoryName": "Museums and Art Galleries",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Department of the Interior Museum",
#         "displayLine2": "Washington, District Of Columbia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Coast Guard Academy - New London, CT",
#         "id": "99596806",
#         "cityID": "3000002921",
#         "type": "POI",
#         "lat": 41.370531,
#         "lon": -72.103396,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "New London",
#         "stateCode": "CT",
#         "provinceName": "Connecticut",
#         "score": 164198.83,
#         "radius": 19.1,
#         "rank": 12.106464,
#         "rank2": 5.928276538848877,
#         "globalScore": 32.282387,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064583,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 7,
#         "poiCategoryName": "Camping and Outdoors",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Coast Guard Academy",
#         "displayLine2": "New London, Connecticut",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Army Medical Department Museum - San Antonio, TX",
#         "id": "132381",
#         "cityID": "3000021763",
#         "type": "POI",
#         "lat": 29.46134,
#         "lon": -98.43807,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Antonio",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 164198.75,
#         "radius": 38.4,
#         "rank": 12.017747,
#         "rank2": 5.928106307983398,
#         "globalScore": 32.282322,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064545,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 14,
#         "poiCategoryName": "Museums and Art Galleries",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Army Medical Department Museum",
#         "displayLine2": "San Antonio, Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Air Force Academy, Cadet Area - Usaf Academy, CO",
#         "id": "99478306",
#         "cityID": "3000002781",
#         "type": "POI",
#         "lat": 39.008333,
#         "lon": -104.890417,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Usaf Academy",
#         "stateCode": "CO",
#         "provinceName": "Colorado",
#         "score": 164198.58,
#         "radius": 28.4,
#         "rank": 11.836448,
#         "rank2": 5.9277544021606445,
#         "globalScore": 32.282185,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064396,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 9,
#         "poiCategoryName": "Colleges and Universities",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Air Force Academy, Cadet Area",
#         "displayLine2": "Usaf Academy, Colorado",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Heart Of Highlands 3br Loft - Louisville, KY",
#         "id": "138799303",
#         "cityID": "3000007866",
#         "type": "HOTEL",
#         "lat": 38.2331,
#         "lon": -85.7117,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Louisville",
#         "stateCode": "KY",
#         "provinceName": "Kentucky",
#         "score": 152194.81,
#         "radius": 30.0,
#         "rank": 0.5,
#         "rank2": 5.8549346923828125,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "US",
#         "address": "1864 EDGELAND AVENUE LOUISVILLE KY 40204 UNITED STATES",
#         "zip": "40204",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Heart Of Highlands 3br Loft",
#         "displayLine2": "Louisville, Kentucky",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Parker's Motel - Lincoln, NH",
#         "id": "5679604",
#         "cityID": "3000014398",
#         "type": "HOTEL",
#         "lat": 44.08985255,
#         "lon": -71.68328851,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lincoln",
#         "stateCode": "NH",
#         "provinceName": "New Hampshire",
#         "score": 152194.81,
#         "radius": 39.4,
#         "rank": 11.862453,
#         "rank2": 47.121917724609375,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.070166,
#         "country": "US",
#         "address": "750 UNITED STATES ROUTE 3 ",
#         "zip": "03251",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Parker's Motel",
#         "displayLine2": "Lincoln, New Hampshire",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Red Roof Inn & Suites Statesboro - University - Statesboro, GA",
#         "id": "2544205",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.44120789,
#         "lon": -81.78367615,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151834.03,
#         "radius": 25.0,
#         "rank": 11.810301,
#         "rank2": 17.92148208618164,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.195726,
#         "country": "US",
#         "address": "316 S MAIN STREET",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Red Roof Inn & Suites Statesboro - University",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hilton Garden Inn Statesville - Statesville, NC",
#         "id": "56431003",
#         "cityID": "3000013302",
#         "type": "HOTEL",
#         "lat": 35.77631554,
#         "lon": -80.86546944,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesville",
#         "stateCode": "NC",
#         "provinceName": "North Carolina",
#         "score": 151834.03,
#         "radius": 27.2,
#         "rank": 1.0,
#         "rank2": 6.794477462768555,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.574251,
#         "country": "US",
#         "address": "1017 GATEWAY CROSSING DRIVE",
#         "zip": "28677",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Hilton Garden Inn Statesville",
#         "displayLine2": "Statesville, North Carolina",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Eagles Nest Inn - Statesboro, GA",
#         "id": "4556805",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.40799332,
#         "lon": -81.782547,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151834.03,
#         "radius": 25.0,
#         "rank": 11.810301,
#         "rank2": 5.927702903747559,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.39699,
#         "country": "US",
#         "address": "225 LANIER DRIVE",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Eagles Nest Inn",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Holiday Inn Express Statesboro - Statesboro, GA",
#         "id": "53753",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.43677902,
#         "lon": -81.78549957,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151834.03,
#         "radius": 25.0,
#         "rank": 11.810301,
#         "rank2": 56.01250457763672,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.504097,
#         "country": "US",
#         "address": "427 S MAIN STREET",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Holiday Inn Express Statesboro",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

airport_data = pd.DataFrame(dictionary_data)

airport_data.head()
# Out:
#           itemName          id      cityID  type        lat         lon  \
# 0      Houston, TX  3000021312  3000021312  CITY  29.763100  -95.363100
# 1    Las Vegas, NV  3000015284  3000015284  CITY  36.175000 -115.136000
# 2      Orlando, FL  3000003349  3000003349  CITY  28.538100  -81.379400
# 3     New York, NY  3000016152  3000016152  CITY  40.759378  -73.985131
# 4  San Antonio, TX  3000021763  3000021763  CITY  29.423900  -98.493300
#
#    proximity savedTravelStartDate savedTravelEndDate     cityName  ...  \
# 0        0.0                 None               None      Houston  ...
# 1        0.0                 None               None    Las Vegas  ...
# 2        0.0                 None               None      Orlando  ...
# 3        0.0                 None               None     New York  ...
# 4        0.0                 None               None  San Antonio  ...
#
#   poiCategoryTypeId poiCategoryName  poiID  seType  gmtOffset        entered  \
# 0                 0            None   None    None       -5.0  united states
# 1                 0            None   None    None       -7.0  united states
# 2                 0            None   None    None       -4.0  united states
# 3                 0            None   None    None       -4.0  united states
# 4                 0            None   None    None       -5.0  united states
#
#    highlightedName  displayLine1  displayLine2 fromSavedSearch
# 0             None       Houston         Texas           False
# 1             None     Las Vegas        Nevada           False
# 2             None       Orlando       Florida           False
# 3             None      New York      New York           False
# 4             None   San Antonio         Texas           False
#
# [5 rows x 34 columns]

# %%
airport_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
airport_data['city'] = airport_data['itemName'].str.split(',').str[0]
airport_data['state'] = airport_data['itemName'].str.split(',').str[1]

column_to_select = ['cityID',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country', 
                    ]

airport_data_select = airport_data[column_to_select]

airport_data_select.head()
# Out:
#        cityID         city state        lat         lon      score  \
# 0  3000021312      Houston    TX  29.763100  -95.363100  203129.89
# 1  3000015284    Las Vegas    NV  36.175000 -115.136000  203110.17
# 2  3000003349      Orlando    FL  28.538100  -81.379400  202668.47
# 3  3000016152     New York    NY  40.759378  -73.985131  202462.61
# 4  3000021763  San Antonio    TX  29.423900  -98.493300  201929.64
#
#          rank       rank2  globalScore country
# 0   66.034960   93.023735   100.000000      US
# 1  100.000000  100.000000    99.954090      US
# 2   82.260895   97.879250    98.932590      US
# 3   88.943530   96.242455    98.459990      US
# 4   62.747860   92.443672    97.246864      US

# %%
airport_data_select.dtypes
# Out:
# cityID          object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# cityID          0
# city            0
# state           0
# lat             0
# lon             0
# score           0
# rank            0
# rank2           0
# globalScore     0
# country         0
# countryName     0
# countryCode     0
# displayLine1    0
# displayLine2    0
# dtype: int64

# %%
# # Create a folder named "data" if it doesn't exist
# if not os.path.exists("data"):
#     os.mkdir("data")

# # Save DataFrame to a CSV file inside the "data" folder
# file_path = os.path.join("data", "airport.csv")
# hotel_data_clean.to_csv(file_path, index=False)

# print("DataFrame saved to 'data/airport.csv' file.")
