# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import os

# Import the Priceline API key
from api_keys import priceline_api_key

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"HOTEL"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Pacific Coast Roadhouse, Surestay Collection BY Best Western - San Simeon, CA",
#         "id": "2211905",
#         "cityID": "3000002266",
#         "type": "HOTEL",
#         "lat": 35.61403,
#         "lon": -121.1449,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Simeon",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400488.72,
#         "radius": 57.9,
#         "rank": 11.810303,
#         "rank2": 99.55961608886719,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.16622,
#         "country": "US",
#         "address": "9280 CASTILLO DRIVE",
#         "zip": "93452",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Pacific Coast Roadhouse, Surestay Collection BY Best Western",
#         "displayLine2": "San Simeon, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Resorts World Catskills - Monticello, NY",
#         "id": "83134405",
#         "cityID": "3000016109",
#         "type": "HOTEL",
#         "lat": 41.657145,
#         "lon": -74.647719,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Monticello",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 400470.22,
#         "radius": 25.0,
#         "rank": 1.0,
#         "rank2": 99.53812408447266,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.147905,
#         "country": "US",
#         "address": "888 RESORTS WORLD DRIVE",
#         "zip": "12701",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Resorts World Catskills",
#         "displayLine2": "Monticello, New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ka'anapali Beach Hotel - Lahaina, HI",
#         "id": "55374",
#         "cityID": "3000004056",
#         "type": "HOTEL",
#         "lat": 20.92363885,
#         "lon": -156.69370919,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lahaina",
#         "stateCode": "HI",
#         "provinceName": "Hawaii",
#         "score": 400379.47,
#         "radius": 42.2,
#         "rank": 13.869067,
#         "rank2": 99.43313598632812,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.338116,
#         "country": "US",
#         "address": "2525 KAANAPALI PARKWAY",
#         "zip": "96761",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -10.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Ka'anapali Beach Hotel",
#         "displayLine2": "Lahaina, Hawaii",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "L\u00bfauberge Casino Resort Lake Charles - Lake Charles, LA",
#         "id": "13051304",
#         "cityID": "3000008374",
#         "type": "HOTEL",
#         "lat": 30.20676,
#         "lon": -93.258332,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lake Charles",
#         "stateCode": "LA",
#         "provinceName": "Louisiana",
#         "score": 400273.38,
#         "radius": 13.4,
#         "rank": 15.117631,
#         "rank2": 99.3105239868164,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.387842,
#         "country": "US",
#         "address": "777 AVENUE L\u00bfAUBERGE",
#         "zip": "70601",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "L\u00bfauberge Casino Resort Lake Charles",
#         "displayLine2": "Lake Charles, Louisiana",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Sunrise Resort Motel South - Clearwater Beach, FL",
#         "id": "18620004",
#         "cityID": "3000003143",
#         "type": "HOTEL",
#         "lat": 27.9739260000001,
#         "lon": -82.8282869999999,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Clearwater Beach",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 400228.28,
#         "radius": 21.3,
#         "rank": 11.810301,
#         "rank2": 99.25850677490234,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.173634,
#         "country": "US",
#         "address": "229 CORONADO DRIVE",
#         "zip": "33767",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Sunrise Resort Motel South",
#         "displayLine2": "Clearwater Beach, Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Americana Inn Motel - South San Francisco, CA",
#         "id": "43042606",
#         "cityID": "3000002333",
#         "type": "HOTEL",
#         "lat": 37.6514166,
#         "lon": -122.43103314,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "South San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400227.44,
#         "radius": 12.3,
#         "rank": 11.811775,
#         "rank2": 99.25753784179688,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.00555,
#         "country": "US",
#         "address": "760 EL CAMINO REAL",
#         "zip": "94080",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Americana Inn Motel",
#         "displayLine2": "South San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Sophie Station Suites - Fairbanks, AK",
#         "id": "56725",
#         "cityID": "3000000060",
#         "type": "HOTEL",
#         "lat": 64.83252,
#         "lon": -147.81251,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Fairbanks",
#         "stateCode": "AK",
#         "provinceName": "Alaska",
#         "score": 400214.28,
#         "radius": 12.1,
#         "rank": 11.810301,
#         "rank2": 99.24235534667969,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.073864,
#         "country": "US",
#         "address": "1717 UNIVERSITY AVENUE",
#         "zip": "99709",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -8.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Sophie Station Suites",
#         "displayLine2": "Fairbanks, Alaska",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Budget Host - Denton, TX",
#         "id": "2186405",
#         "cityID": "3000021100",
#         "type": "HOTEL",
#         "lat": 33.19427,
#         "lon": -97.11797,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Denton",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 400214.28,
#         "radius": 51.2,
#         "rank": 11.810301,
#         "rank2": 99.24235534667969,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.088646,
#         "country": "US",
#         "address": "1500 DALLAS DRIVE",
#         "zip": "76205",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Budget Host",
#         "displayLine2": "Denton, Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Wine Country Inn - Palisade, CO",
#         "id": "14130004",
#         "cityID": "3000002719",
#         "type": "HOTEL",
#         "lat": 39.119309,
#         "lon": -108.364976,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Palisade",
#         "stateCode": "CO",
#         "provinceName": "Colorado",
#         "score": 400161.38,
#         "radius": 25.0,
#         "rank": 11.813059,
#         "rank2": 99.18133544921875,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.048014,
#         "country": "US",
#         "address": "777 GRANDE RIVER DRIVE",
#         "zip": "81526",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Wine Country Inn",
#         "displayLine2": "Palisade, Colorado",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ingleside Motel - Athens, TN",
#         "id": "121538803",
#         "cityID": "3000020336",
#         "type": "HOTEL",
#         "lat": 35.44329,
#         "lon": -84.63408,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Athens",
#         "stateCode": "TN",
#         "provinceName": "Tennessee",
#         "score": 400137.97,
#         "radius": 24.2,
#         "rank": 0.5,
#         "rank2": 99.15431213378906,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.00739,
#         "country": "US",
#         "address": "2214 CONGRESS PARKWAY S",
#         "zip": "37303",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Ingleside Motel",
#         "displayLine2": "Athens, Tennessee",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

hotel_data = pd.DataFrame(dictionary_data)

hotel_data.head()
# Out:
#                                             itemName        id      cityID  \
# 0  Pacific Coast Roadhouse, Surestay Collection B...   2211905  3000002266
# 1           Resorts World Catskills - Monticello, NY  83134405  3000016109
# 2               Ka'anapali Beach Hotel - Lahaina, HI     55374  3000004056
# 3  L¿auberge Casino Resort Lake Charles - Lake Ch...  13051304  3000008374
# 4  Sunrise Resort Motel South - Clearwater Beach, FL  18620004  3000003143
#
#     type        lat         lon  proximity savedTravelStartDate  \
# 0  HOTEL  35.614030 -121.144900        0.0                 None
# 1  HOTEL  41.657145  -74.647719        0.0                 None
# 2  HOTEL  20.923639 -156.693709        0.0                 None
# 3  HOTEL  30.206760  -93.258332        0.0                 None
# 4  HOTEL  27.973926  -82.828287        0.0                 None
#
#   savedTravelEndDate          cityName  ... poiCategoryTypeId poiCategoryName  \
# 0               None        San Simeon  ...                 0            None
# 1               None        Monticello  ...                 0            None
# 2               None           Lahaina  ...                 0            None
# 3               None      Lake Charles  ...                 0            None
# 4               None  Clearwater Beach  ...                 0            None
#
#    poiID  seType  gmtOffset        entered  highlightedName  \
# 0   None    None       -7.0  united states             None
# 1   None    None       -4.0  united states             None
# 2   None    None      -10.0  united states             None
# 3   None    None       -5.0  united states             None
# 4   None    None       -4.0  united states             None
#
#                                         displayLine1  \
# 0  Pacific Coast Roadhouse, Surestay Collection B...
# 1                            Resorts World Catskills
# 2                             Ka'anapali Beach Hotel
# 3               L¿auberge Casino Resort Lake Charles
# 4                         Sunrise Resort Motel South
#
#                 displayLine2 fromSavedSearch
# 0     San Simeon, California           False
# 1       Monticello, New York           False
# 2            Lahaina, Hawaii           False
# 3    Lake Charles, Louisiana           False
# 4  Clearwater Beach, Florida           False
#
# [5 rows x 34 columns]

# %%
hotel_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
hotel_data['city'] = hotel_data['itemName'].str.split(',').str[0]
hotel_data['state'] = hotel_data['itemName'].str.split(',').str[1]

column_to_select = ['cityID',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country' 
                    ]

hotel_data_select = hotel_data[column_to_select]

hotel_data_select.head()
# Out:
#        cityID                                               city  \
# 0  3000002266                            Pacific Coast Roadhouse
# 1  3000016109               Resorts World Catskills - Monticello
# 2  3000004056                   Ka'anapali Beach Hotel - Lahaina
# 3  3000008374  L¿auberge Casino Resort Lake Charles - Lake Ch...
# 4  3000003143      Sunrise Resort Motel South - Clearwater Beach
#
#                                                state        lat         lon  \
# 0   Surestay Collection BY Best Western - San Simeon  35.614030 -121.144900
# 1                                                 NY  41.657145  -74.647719
# 2                                                 HI  20.923639 -156.693709
# 3                                                 LA  30.206760  -93.258332
# 4                                                 FL  27.973926  -82.828287
#
#        score       rank      rank2  globalScore country
# 0  400488.72  11.810303  99.559616         30.0      US
# 1  400470.22   1.000000  99.538124         30.0      US
# 2  400379.47  13.869067  99.433136         30.0      US
# 3  400273.38  15.117631  99.310524         30.0      US
# 4  400228.28  11.810301  99.258507         30.0      US

# %%
hotel_data_select.dtypes
# Out:
# cityID          object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# cityID         0
# city           0
# state          0
# lat            0
# lon            0
# score          0
# rank           0
# rank2          0
# globalScore    0
# country        0
# dtype: int64

# %%
# # Create a folder named "data" if it doesn't exist
# if not os.path.exists("data"):
#     os.mkdir("data")

# # Save DataFrame to a CSV file inside the "data" folder
# file_path = os.path.join("data", "hotel.csv")
# hotel_data_clean.to_csv(file_path, index=False)

# print("DataFrame saved to 'data/hotel.csv' file.")

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"AIRPORT"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Houston, TX",
#         "id": "3000021312",
#         "cityID": "3000021312",
#         "type": "CITY",
#         "lat": 29.7631,
#         "lon": -95.3631,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 203106.39,
#         "radius": 39.6,
#         "rank": 66.03496,
#         "rank2": 93.02373504638672,
#         "globalScore": 100.0,
#         "globalScoreReducedCityBoost": 58.286484,
#         "globalScoreWOHotelCountNormalize": 46.649864,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Las Vegas, NV",
#         "id": "3000015284",
#         "cityID": "3000015284",
#         "type": "CITY",
#         "lat": 36.175,
#         "lon": -115.136,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 203086.67,
#         "radius": 28.0,
#         "rank": 100.0,
#         "rank2": 100.0,
#         "globalScore": 99.95409,
#         "globalScoreReducedCityBoost": 100.0,
#         "globalScoreWOHotelCountNormalize": 100.0,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Orlando, FL",
#         "id": "3000003349",
#         "cityID": "3000003349",
#         "type": "CITY",
#         "lat": 28.5381,
#         "lon": -81.3794,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Orlando",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 202644.97,
#         "radius": 33.7,
#         "rank": 82.260895,
#         "rank2": 97.8792495727539,
#         "globalScore": 98.93259,
#         "globalScoreReducedCityBoost": 65.36813,
#         "globalScoreWOHotelCountNormalize": 56.468636,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Orlando",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "New York, NY",
#         "id": "3000016152",
#         "cityID": "3000016152",
#         "type": "CITY",
#         "lat": 40.759378,
#         "lon": -73.985131,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "New York",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 202439.11,
#         "radius": 15.9,
#         "rank": 88.94353,
#         "rank2": 96.2424545288086,
#         "globalScore": 98.45999,
#         "globalScoreReducedCityBoost": 52.378162,
#         "globalScoreWOHotelCountNormalize": 46.737076,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "New York",
#         "displayLine2": "New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "San Antonio, TX",
#         "id": "3000021763",
#         "cityID": "3000021763",
#         "type": "CITY",
#         "lat": 29.4239,
#         "lon": -98.4933,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Antonio",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 201906.14,
#         "radius": 38.4,
#         "rank": 62.74786,
#         "rank2": 92.44367218017578,
#         "globalScore": 97.246864,
#         "globalScoreReducedCityBoost": 49.077602,
#         "globalScoreWOHotelCountNormalize": 40.708843,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "San Antonio",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Atlanta, GA",
#         "id": "3000003496",
#         "cityID": "3000003496",
#         "type": "CITY",
#         "lat": 33.7489,
#         "lon": -84.3881,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Atlanta",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 201835.9,
#         "radius": 37.0,
#         "rank": 71.75888,
#         "rank2": 93.99879455566406,
#         "globalScore": 97.08815,
#         "globalScoreReducedCityBoost": 53.231205,
#         "globalScoreWOHotelCountNormalize": 44.350124,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Atlanta",
#         "displayLine2": "Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Ellington Airport (EFD) , TX",
#         "id": "EFD",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.649992940224973,
#         "lon": -95.283339696492,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 192983.27,
#         "radius": 39.6,
#         "rank": 12.332901,
#         "rank2": 43.747379302978516,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.074444,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - Ellington Airport (EFD)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "William P. Hobby Airport (HOU) , TX",
#         "id": "HOU",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.645180094745875,
#         "lon": -95.27864144257192,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 192983.27,
#         "radius": 39.6,
#         "rank": 33.20637,
#         "rank2": 76.55439758300781,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.199505,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - William P. Hobby Airport (HOU)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "George Bush Intercontinental Airport (IAH) , TX",
#         "id": "IAH",
#         "cityID": "3000021312",
#         "type": "AIRPORT",
#         "lat": 29.98672023642336,
#         "lon": -95.34223975783146,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Houston",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 192983.27,
#         "radius": 39.6,
#         "rank": 40.247612,
#         "rank2": 79.82408905029297,
#         "globalScore": 79.0,
#         "globalScoreReducedCityBoost": 55.92928,
#         "globalScoreWOHotelCountNormalize": 44.292503,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Houston - George Bush Intercontinental Airport (IAH)",
#         "displayLine2": "Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Harry Reid Intl Airport (LAS) , NV",
#         "id": "LAS",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 36.08167337368651,
#         "lon": -115.15489113033726,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 192965.75,
#         "radius": 28.0,
#         "rank": 35.791367,
#         "rank2": 80.38639831542969,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 65.631096,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - Harry Reid Intl Airport (LAS)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "North Las Vegas Airport (VGT) , NV",
#         "id": "VGT",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 36.183316086542725,
#         "lon": -115.13329062146084,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 192965.75,
#         "radius": 28.0,
#         "rank": 20.259972,
#         "rank2": 64.59667205810547,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 64.87798,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - North Las Vegas Airport (VGT)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Henderson Executive Airport (HSH) , NV",
#         "id": "HSH",
#         "cityID": "3000015284",
#         "type": "AIRPORT",
#         "lat": 35.97441567443802,
#         "lon": -115.13541056530282,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Las Vegas",
#         "stateCode": "NV",
#         "provinceName": "Nevada",
#         "score": 192965.75,
#         "radius": 28.0,
#         "rank": 0.5,
#         "rank2": 55.4843864440918,
#         "globalScore": 78.96773,
#         "globalScoreReducedCityBoost": 94.166664,
#         "globalScoreWOHotelCountNormalize": 64.84516,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Las Vegas - Henderson Executive Airport (HSH)",
#         "displayLine2": "Nevada",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Military Academy - West Point, NY",
#         "id": "63670",
#         "cityID": "3000016595",
#         "type": "POI",
#         "lat": 41.377613,
#         "lon": -73.963524,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "West Point",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 164080.19,
#         "radius": 50.0,
#         "rank": 16.673111,
#         "rank2": 5.93569278717041,
#         "globalScore": 32.28524,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.067547,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 13,
#         "poiCategoryName": "Monuments and Landmarks",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Military Academy",
#         "displayLine2": "West Point, New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Sheep Experiment Station - Lima, MT",
#         "id": "183853",
#         "cityID": "3000012642",
#         "type": "POI",
#         "lat": 44.56659,
#         "lon": -111.58413,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lima",
#         "stateCode": "MT",
#         "provinceName": "Montana",
#         "score": 164076.89,
#         "radius": 25.0,
#         "rank": 12.555779,
#         "rank2": 5.9291205406188965,
#         "globalScore": 32.28271,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064873,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 26,
#         "poiCategoryName": "Other",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Sheep Experiment Station",
#         "displayLine2": "Lima, Montana",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Department of the Interior Museum - Washington, DC",
#         "id": "110273",
#         "cityID": "3000003032",
#         "type": "POI",
#         "lat": 38.88233,
#         "lon": -77.04275,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Washington",
#         "stateCode": "DC",
#         "provinceName": "District Of Columbia",
#         "score": 164076.89,
#         "radius": 19.9,
#         "rank": 12.555779,
#         "rank2": 5.9291205406188965,
#         "globalScore": 32.28271,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064884,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 14,
#         "poiCategoryName": "Museums and Art Galleries",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Department of the Interior Museum",
#         "displayLine2": "Washington, District Of Columbia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Coast Guard Academy - New London, CT",
#         "id": "99596806",
#         "cityID": "3000002921",
#         "type": "POI",
#         "lat": 41.370531,
#         "lon": -72.103396,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "New London",
#         "stateCode": "CT",
#         "provinceName": "Connecticut",
#         "score": 164076.45,
#         "radius": 19.1,
#         "rank": 12.106464,
#         "rank2": 5.928276538848877,
#         "globalScore": 32.282387,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064583,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 7,
#         "poiCategoryName": "Camping and Outdoors",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Coast Guard Academy",
#         "displayLine2": "New London, Connecticut",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Army Medical Department Museum - San Antonio, TX",
#         "id": "132381",
#         "cityID": "3000021763",
#         "type": "POI",
#         "lat": 29.46134,
#         "lon": -98.43807,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Antonio",
#         "stateCode": "TX",
#         "provinceName": "Texas",
#         "score": 164076.38,
#         "radius": 38.4,
#         "rank": 12.017747,
#         "rank2": 5.928106307983398,
#         "globalScore": 32.282322,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064545,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 14,
#         "poiCategoryName": "Museums and Art Galleries",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Army Medical Department Museum",
#         "displayLine2": "San Antonio, Texas",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "United States Air Force Academy, Cadet Area - Usaf Academy, CO",
#         "id": "99478306",
#         "cityID": "3000002781",
#         "type": "POI",
#         "lat": 39.008333,
#         "lon": -104.890417,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Usaf Academy",
#         "stateCode": "CO",
#         "provinceName": "Colorado",
#         "score": 164076.2,
#         "radius": 28.4,
#         "rank": 11.836448,
#         "rank2": 5.9277544021606445,
#         "globalScore": 32.282185,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.064396,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 9,
#         "poiCategoryName": "Colleges and Universities",
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "United States Air Force Academy, Cadet Area",
#         "displayLine2": "Usaf Academy, Colorado",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Parker's Motel - Lincoln, NH",
#         "id": "5679604",
#         "cityID": "3000014398",
#         "type": "HOTEL",
#         "lat": 44.08985255,
#         "lon": -71.68328851,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lincoln",
#         "stateCode": "NH",
#         "provinceName": "New Hampshire",
#         "score": 152168.25,
#         "radius": 39.4,
#         "rank": 11.862453,
#         "rank2": 47.121917724609375,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.070166,
#         "country": "US",
#         "address": "750 UNITED STATES ROUTE 3 ",
#         "zip": "03251",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Parker's Motel",
#         "displayLine2": "Lincoln, New Hampshire",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Heart Of Highlands 3br Loft - Louisville, KY",
#         "id": "138799303",
#         "cityID": "3000007866",
#         "type": "HOTEL",
#         "lat": 38.2331,
#         "lon": -85.7117,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Louisville",
#         "stateCode": "KY",
#         "provinceName": "Kentucky",
#         "score": 152168.25,
#         "radius": 30.0,
#         "rank": 0.5,
#         "rank2": 5.8549346923828125,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "US",
#         "address": "1864 EDGELAND AVENUE LOUISVILLE KY 40204 UNITED STATES",
#         "zip": "40204",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Heart Of Highlands 3br Loft",
#         "displayLine2": "Louisville, Kentucky",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Holiday Inn Statesboro-University Area - Statesboro, GA",
#         "id": "9108603",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.42824361,
#         "lon": -81.75556205,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151810.53,
#         "radius": 25.0,
#         "rank": 12.033743,
#         "rank2": 19.679338455200195,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.609337,
#         "country": "US",
#         "address": "455 COMMERCE DRIVE",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Holiday Inn Statesboro-University Area",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Fairfield Inn & Suites Statesville - Statesville, NC",
#         "id": "163847803",
#         "cityID": "3000013302",
#         "type": "HOTEL",
#         "lat": 35.80884,
#         "lon": -80.87826,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesville",
#         "stateCode": "NC",
#         "provinceName": "North Carolina",
#         "score": 151810.53,
#         "radius": 27.2,
#         "rank": 0.5,
#         "rank2": 9.372452735900879,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.260351,
#         "country": "US",
#         "address": "1243 Tonewood Street",
#         "zip": "28677",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Fairfield Inn & Suites Statesville",
#         "displayLine2": "Statesville, North Carolina",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Days Inn BY Wyndham Statesville - Statesville, NC",
#         "id": "45515",
#         "cityID": "3000013302",
#         "type": "HOTEL",
#         "lat": 35.80768809,
#         "lon": -80.87897658,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesville",
#         "stateCode": "NC",
#         "provinceName": "North Carolina",
#         "score": 151810.53,
#         "radius": 27.2,
#         "rank": 11.810301,
#         "rank2": 10.67800235748291,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 31.351603,
#         "country": "US",
#         "address": "703 GAITHER ROAD",
#         "zip": "28677",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Days Inn BY Wyndham Statesville",
#         "displayLine2": "Statesville, North Carolina",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Days Inn BY Wyndham Statesboro - Statesboro, GA",
#         "id": "54357",
#         "cityID": "3000003919",
#         "type": "HOTEL",
#         "lat": 32.43232727,
#         "lon": -81.77883148,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Statesboro",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 151810.53,
#         "radius": 25.0,
#         "rank": 11.812754,
#         "rank2": 61.35292053222656,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.638893,
#         "country": "US",
#         "address": "616 FAIR ROAD",
#         "zip": "30458",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Days Inn BY Wyndham Statesboro",
#         "displayLine2": "Statesboro, Georgia",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

airport_data = pd.DataFrame(dictionary_data)

airport_data.head()
# Out:
#           itemName          id      cityID  type        lat         lon  \
# 0      Houston, TX  3000021312  3000021312  CITY  29.763100  -95.363100
# 1    Las Vegas, NV  3000015284  3000015284  CITY  36.175000 -115.136000
# 2      Orlando, FL  3000003349  3000003349  CITY  28.538100  -81.379400
# 3     New York, NY  3000016152  3000016152  CITY  40.759378  -73.985131
# 4  San Antonio, TX  3000021763  3000021763  CITY  29.423900  -98.493300
#
#    proximity savedTravelStartDate savedTravelEndDate     cityName  ...  \
# 0        0.0                 None               None      Houston  ...
# 1        0.0                 None               None    Las Vegas  ...
# 2        0.0                 None               None      Orlando  ...
# 3        0.0                 None               None     New York  ...
# 4        0.0                 None               None  San Antonio  ...
#
#   poiCategoryTypeId poiCategoryName  poiID  seType  gmtOffset        entered  \
# 0                 0            None   None    None       -5.0  united states
# 1                 0            None   None    None       -7.0  united states
# 2                 0            None   None    None       -4.0  united states
# 3                 0            None   None    None       -4.0  united states
# 4                 0            None   None    None       -5.0  united states
#
#    highlightedName  displayLine1  displayLine2 fromSavedSearch
# 0             None       Houston         Texas           False
# 1             None     Las Vegas        Nevada           False
# 2             None       Orlando       Florida           False
# 3             None      New York      New York           False
# 4             None   San Antonio         Texas           False
#
# [5 rows x 34 columns]

# %%
airport_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
airport_data['city'] = airport_data['itemName'].str.split(',').str[0]
airport_data['state'] = airport_data['itemName'].str.split(',').str[1]

column_to_select = ['cityID',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country' 
                    ]

airport_data_select = airport_data[column_to_select]

airport_data_select.head()
# Out:
#        cityID         city state        lat         lon      score  \
# 0  3000021312      Houston    TX  29.763100  -95.363100  203106.39
# 1  3000015284    Las Vegas    NV  36.175000 -115.136000  203086.67
# 2  3000003349      Orlando    FL  28.538100  -81.379400  202644.97
# 3  3000016152     New York    NY  40.759378  -73.985131  202439.11
# 4  3000021763  San Antonio    TX  29.423900  -98.493300  201906.14
#
#          rank       rank2  globalScore country
# 0   66.034960   93.023735   100.000000      US
# 1  100.000000  100.000000    99.954090      US
# 2   82.260895   97.879250    98.932590      US
# 3   88.943530   96.242455    98.459990      US
# 4   62.747860   92.443672    97.246864      US

# %%
airport_data_select.dtypes
# Out:
# cityID          object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# cityID         0
# city           0
# state          0
# lat            0
# lon            0
# score          0
# rank           0
# rank2          0
# globalScore    0
# country        0
# dtype: int64

# %%
# # Create a folder named "data" if it doesn't exist
# if not os.path.exists("data"):
#     os.mkdir("data")

# # Save DataFrame to a CSV file inside the "data" folder
# file_path = os.path.join("data", "airport.csv")
# hotel_data_clean.to_csv(file_path, index=False)

# print("DataFrame saved to 'data/airport.csv' file.")
