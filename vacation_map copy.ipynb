# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import os

## Import the Priceline API key
from api_keys import priceline_api_key

# %%
# List of cities
city_list = [
    'San Jose, CA',
    'Santa Cruz, CA',
    'Newport Beach, CA',
    'Napa, CA',
    'Santa Monica, CA',
    'Long Beach, CA',
    'Fresno, CA',
    'Monterey, CA',
    'Santa Barbara, CA',
    'Palm Springs, CA',
    'Sacramento, CA',
    'Anaheim, CA',
    'San Diego, CA',
    'Los Angeles, CA',
    'San Francisco, CA',
]

# Initialize an empty list to store DataFrames
dfs = []

# # Loop through each city in the list
# for city in city_list:
#     url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"
    
#     querystring = {"name": city, "search_type": "HOTEL"}

#     headers = {
#         "X-RapidAPI-Key": priceline_api_key,
#         "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
#     }
    
#     response = requests.get(url, headers=headers, params=querystring)

#     if response.status_code == 200:

#         # Load the JSON response data into a list
#         list_data = json.loads(response.text)
        
#         # Create a DataFrame for the current city and append it to the list
#         hotel_data = pd.DataFrame(list_data)
#         dfs.append(hotel_data)

        
#         # Get the JSON data
#         json_data = response.json()
        
#         # Use json.dumps with 'indent' parameter to pretty-print the JSON data
#         json_data = json.dumps(response.json(), indent=4)
        
#         print(f"Hotel data for {city}:")
#         print(json_data)
#     else:
#         print(f"Failed to get data for {city}. Status code:", response.status_code)
        
        
# Loop through each city in the list
for city in city_list:
    url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"
    
    querystring = {"name": city, "search_type": "HOTEL"}

    headers = {
        "X-RapidAPI-Key": priceline_api_key,
        "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
    }
    
    while True:
        response = requests.get(url, headers=headers, params=querystring)

        if response.status_code == 200:
            # Get the JSON data
            json_data = response.json()

            # Check if response type is "HOTEL"
            if json_data[0].get('type') == 'HOTEL':
                
                # Load the JSON response data into a list
                list_data = json.loads(response.text)
        
                # Create a DataFrame for the current city and append it to the list
                hotel_data = pd.DataFrame(list_data)
                dfs.append(hotel_data)
                
                # Use json.dumps with 'indent' parameter to pretty-print the JSON data
                json_data_pretty = json.dumps(json_data, indent=4)
                
                print(f"Hotel data for {city}:")
                print(json_data_pretty)
                
                break  # Exit the while loop if data is successfully retrieved
            else:
                print(f"Response type for {city} is not 'HOTEL'. Retrying...")
        else:
            print(f"Failed to get data for {city}. Status code:", response.status_code)
            break  # Exit the while loop on error
# Out:
# Response type for San Jose, CA is not 'HOTEL'. Retrying...
# Hotel data for San Jose, CA:
# [
#     {
#         "itemName": "Roseview House - San Jose, CA",
#         "id": "125194804",
#         "cityID": "3000002250",
#         "type": "HOTEL",
#         "lat": 37.3302,
#         "lon": -121.89728,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400809.66,
#         "radius": 23.9,
#         "rank": 1.0,
#         "rank2": 97.81724548339844,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "396 W SAN FERNANDO ST",
#         "zip": "95112",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Roseview House",
#         "displayLine2": "San Jose, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Boutique Hotel Calle 20 - San Jose, Costa Rica",
#         "id": "13453403",
#         "cityID": "3000070002",
#         "type": "HOTEL",
#         "lat": 9.93755009,
#         "lon": -84.08710241,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose",
#         "stateCode": null,
#         "provinceName": "San Jose",
#         "score": 398971.72,
#         "radius": 100.0,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "COSTA RICA",
#         "address": "350 METROS AL NORTE DEL HOSPITAL NACIONAL DE NI\u00bfOS ENTRE AVENIDA 3 Y 5 CALLE 20",
#         "zip": null,
#         "countryName": "COSTA RICA",
#         "countryCode": "CS",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Boutique Hotel Calle 20",
#         "displayLine2": "San Jose, Costa Rica",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Casa Lima B&B - San Jose, Costa Rica",
#         "id": "42958406",
#         "cityID": "3000070002",
#         "type": "HOTEL",
#         "lat": 9.94514829,
#         "lon": -84.12525013,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose",
#         "stateCode": null,
#         "provinceName": "San Jose",
#         "score": 398971.72,
#         "radius": 100.0,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.007387,
#         "country": "COSTA RICA",
#         "address": "AV 25 ENTRE CALLE 100 Y 102",
#         "zip": null,
#         "countryName": "COSTA RICA",
#         "countryCode": "CS",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Casa Lima B&B",
#         "displayLine2": "San Jose, Costa Rica",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "El Mirador Del Valle - San Jose Del Valle, Spain",
#         "id": "23075205",
#         "cityID": "5000371869",
#         "type": "HOTEL",
#         "lat": 36.6128989,
#         "lon": -5.80448135,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose Del Valle",
#         "stateCode": null,
#         "provinceName": "Andalucia",
#         "score": 398971.7,
#         "radius": 9.8,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "SPAIN",
#         "address": "2 CALLE PARADA ALTA",
#         "zip": null,
#         "countryName": "SPAIN",
#         "countryCode": "SP",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": 2.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "El Mirador Del Valle",
#         "displayLine2": "San Jose Del Valle, Spain",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "La Caseta De Jose - Sueca, Spain",
#         "id": "20960403",
#         "cityID": "5000043954",
#         "type": "HOTEL",
#         "lat": 39.24842345,
#         "lon": -0.26027219,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Sueca",
#         "stateCode": null,
#         "provinceName": "Comunidad Valenciana",
#         "score": 398971.62,
#         "radius": 7.5,
#         "rank": 11.809777,
#         "rank2": 97.8209228515625,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "SPAIN",
#         "address": "SAN VICENTE DE RODA 22",
#         "zip": null,
#         "countryName": "SPAIN",
#         "countryCode": "SP",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": 2.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "La Caseta De Jose",
#         "displayLine2": "Sueca, Spain",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hostal San Carlos - Lloret De Mar, Spain",
#         "id": "55974405",
#         "cityID": "5000300440",
#         "type": "HOTEL",
#         "lat": 41.7011327,
#         "lon": 2.84668743,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Lloret De Mar",
#         "stateCode": null,
#         "provinceName": "Cataluna",
#         "score": 398971.62,
#         "radius": 5.0,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "SPAIN",
#         "address": "JOSEP LLUHI 21",
#         "zip": null,
#         "countryName": "SPAIN",
#         "countryCode": "SP",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": 2.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Hostal San Carlos",
#         "displayLine2": "Lloret De Mar, Spain",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Cascada De Las Animas - San Jose De Maipo, Chile",
#         "id": "46288504",
#         "cityID": "5000457583",
#         "type": "HOTEL",
#         "lat": -33.5844238,
#         "lon": -70.395851,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose De Maipo",
#         "stateCode": null,
#         "provinceName": "Region Metropolitana",
#         "score": 398971.44,
#         "radius": 30.9,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "CHILE",
#         "address": "CAMINO AL VOLCAN 31087",
#         "zip": null,
#         "countryName": "CHILE",
#         "countryCode": "CI",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Cascada De Las Animas",
#         "displayLine2": "San Jose De Maipo, Chile",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hotel Real Del Campo - San Jose Chiquilaja, Guatemala",
#         "id": "47081504",
#         "cityID": "5000341432",
#         "type": "HOTEL",
#         "lat": 14.8458556,
#         "lon": -91.48429155,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose Chiquilaja",
#         "stateCode": null,
#         "provinceName": "Quezaltenango",
#         "score": 398971.38,
#         "radius": 22.9,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "GUATEMALA",
#         "address": "KILOMETRO 224 SALIDA A LA COSTA SUR HOTEL REAL DEL CAMPO ANTIGUO ANEXO HOTEL DEL CAMPO",
#         "zip": null,
#         "countryName": "GUATEMALA",
#         "countryCode": "GT",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Hotel Real Del Campo",
#         "displayLine2": "San Jose Chiquilaja, Guatemala",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Caba\u00f1as San Jose - La Estancia, Argentina",
#         "id": "44384704",
#         "cityID": "5000101363",
#         "type": "HOTEL",
#         "lat": -31.77119272,
#         "lon": -64.54433441,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "La Estancia",
#         "stateCode": null,
#         "provinceName": "Cordoba",
#         "score": 398971.34,
#         "radius": 9.1,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "ARGENTINA",
#         "address": "Avenida Malvinas Argentinas",
#         "zip": null,
#         "countryName": "ARGENTINA",
#         "countryCode": "AR",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -3.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Caba\u00f1as San Jose",
#         "displayLine2": "La Estancia, Argentina",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Caba\u00bfas El Coyote - San Jose, Costa Rica",
#         "id": "61665604",
#         "cityID": "3000070002",
#         "type": "HOTEL",
#         "lat": 9.69639604,
#         "lon": -84.05108303,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Jose",
#         "stateCode": null,
#         "provinceName": "San Jose",
#         "score": 398971.1,
#         "radius": 100.0,
#         "rank": 7.071068,
#         "rank2": 97.82015991210938,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "COSTA RICA",
#         "address": "SAN PABLO LE\u00bfN CORT\u00bf",
#         "zip": null,
#         "countryName": "COSTA RICA",
#         "countryCode": "CS",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -6.0,
#         "entered": "san jose ca",
#         "highlightedName": null,
#         "displayLine1": "Caba\u00bfas El Coyote",
#         "displayLine2": "San Jose, Costa Rica",
#         "fromSavedSearch": false
#     }
# ]
# Hotel data for Santa Cruz, CA:
# [
#     {
#         "itemName": "Surf City Inn & Suites - Santa Cruz, CA",
#         "id": "42212",
#         "cityID": "3000002273",
#         "type": "HOTEL",
#         "lat": 36.96986,
#         "lon": -122.01988,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400925.7,
#         "radius": 16.5,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.341616,
#         "country": "US",
#         "address": "619 RIVERSIDE AVENUE",
#         "zip": "95060",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Surf City Inn & Suites",
#         "displayLine2": "Santa Cruz, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Villa Vista - Santa Cruz, CA",
#         "id": "71834504",
#         "cityID": "3000002273",
#         "type": "HOTEL",
#         "lat": 36.9558654,
#         "lon": -121.9775194,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400922.5,
#         "radius": 16.5,
#         "rank": 1.0,
#         "rank2": 97.81724548339844,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "22800 EAST CLIFF DRIVE",
#         "zip": "95062",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Villa Vista",
#         "displayLine2": "Santa Cruz, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Magical Oasis - Santa Cruz, CA",
#         "id": "77022303",
#         "cityID": "3000002273",
#         "type": "HOTEL",
#         "lat": 36.956323,
#         "lon": -122.025119,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400921.56,
#         "radius": 16.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "null",
#         "zip": "95060",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Magical Oasis",
#         "displayLine2": "Santa Cruz, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Villa Vanuza - Santa Cruz Cabralia, Brazil",
#         "id": "19474403",
#         "cityID": "5000464048",
#         "type": "HOTEL",
#         "lat": -16.2801791,
#         "lon": -39.029648,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz Cabralia",
#         "stateCode": null,
#         "provinceName": "Bahia",
#         "score": 400579.53,
#         "radius": 7.2,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "BRAZIL",
#         "address": "ESTRADA DE MINAS 95",
#         "zip": null,
#         "countryName": "BRAZIL",
#         "countryCode": "BR",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -3.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Villa Vanuza",
#         "displayLine2": "Santa Cruz Cabralia, Brazil",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Casa De F\u00bfas Casa Mia - Santa Cruz Cabralia, Brazil",
#         "id": "39342403",
#         "cityID": "5000464048",
#         "type": "HOTEL",
#         "lat": -16.29405933,
#         "lon": -39.02836198,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz Cabralia",
#         "stateCode": null,
#         "provinceName": "Bahia",
#         "score": 400575.78,
#         "radius": 7.2,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "BRAZIL",
#         "address": "RUA 25 DE ABRIL",
#         "zip": null,
#         "countryName": "BRAZIL",
#         "countryCode": "BR",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -3.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Casa De F\u00bfas Casa Mia",
#         "displayLine2": "Santa Cruz Cabralia, Brazil",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hotel Santa Cruz Mochis - Los Mochis, Sinaloa, Mexico",
#         "id": "38106904",
#         "cityID": "5000495647",
#         "type": "HOTEL",
#         "lat": 25.78111559,
#         "lon": -108.98697721,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Mochis",
#         "stateCode": "SI",
#         "provinceName": "Sinaloa",
#         "score": 398971.9,
#         "radius": 13.8,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "MEXICO",
#         "address": "CALLEJON TENOCHTITLAN 554 ORIENTE",
#         "zip": null,
#         "countryName": "MEXICO",
#         "countryCode": "MX",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Hotel Santa Cruz Mochis",
#         "displayLine2": "Los Mochis, Sinaloa, Mexico",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Casa Roble A\u00f1ejo Bed & Breakfast - Santa Cruz, Chile",
#         "id": "46146204",
#         "cityID": "5000457626",
#         "type": "HOTEL",
#         "lat": -34.63313425,
#         "lon": -71.35668933,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz",
#         "stateCode": null,
#         "provinceName": "Libertador General Bernado Ohiggin",
#         "score": 398971.75,
#         "radius": 16.5,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "CHILE",
#         "address": "CALLE EL BOSQUE N\u00ba 1029 VILLA AMANECER SANTA CRUZ",
#         "zip": null,
#         "countryName": "CHILE",
#         "countryCode": "CI",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Casa Roble A\u00f1ejo Bed & Breakfast",
#         "displayLine2": "Santa Cruz, Chile",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Lili's Hostel - Santa Cruz De La Sierra, Bolivia",
#         "id": "49756404",
#         "cityID": "5000458511",
#         "type": "HOTEL",
#         "lat": -17.77826471,
#         "lon": -63.1709476,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz De La Sierra",
#         "stateCode": null,
#         "provinceName": "Santa Cruz",
#         "score": 398971.7,
#         "radius": 5.0,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "BOLIVIA",
#         "address": "CALLE OTUQUIS 161 ENTRE LA SUAREZ ARANA Y CHARCAS ",
#         "zip": null,
#         "countryName": "BOLIVIA",
#         "countryCode": "BL",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Lili's Hostel",
#         "displayLine2": "Santa Cruz De La Sierra, Bolivia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hotel Libertador Simon Bolivar - Santa Cruz De La Sierra, Bolivia",
#         "id": "49756604",
#         "cityID": "5000458511",
#         "type": "HOTEL",
#         "lat": -17.78080459,
#         "lon": -63.18295709,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz De La Sierra",
#         "stateCode": null,
#         "provinceName": "Santa Cruz",
#         "score": 398971.7,
#         "radius": 5.0,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "BOLIVIA",
#         "address": "CALLE BUENOS AIRES 119 ESQUINA LIBERTAD",
#         "zip": null,
#         "countryName": "BOLIVIA",
#         "countryCode": "BL",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Hotel Libertador Simon Bolivar",
#         "displayLine2": "Santa Cruz De La Sierra, Bolivia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Gran Hotel Canada - Santa Cruz De La Sierra, Bolivia",
#         "id": "49583004",
#         "cityID": "5000458511",
#         "type": "HOTEL",
#         "lat": -17.77982637,
#         "lon": -63.17510962,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Santa Cruz De La Sierra",
#         "stateCode": null,
#         "provinceName": "Santa Cruz",
#         "score": 398971.7,
#         "radius": 5.0,
#         "rank": 9.036321,
#         "rank2": 97.82052612304688,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "BOLIVIA",
#         "address": "CHARCAS 595 Y ABAROA",
#         "zip": null,
#         "countryName": "BOLIVIA",
#         "countryCode": "BL",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "santa cruz ca",
#         "highlightedName": null,
#         "displayLine1": "Gran Hotel Canada",
#         "displayLine2": "Santa Cruz De La Sierra, Bolivia",
#         "fromSavedSearch": false
#     }
# ]
# Hotel data for Newport Beach, CA:
# [
#     {
#         "itemName": "Newport Beach Simplicity I & Ii - Newport Beach, CA",
#         "id": "86227506",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.61531,
#         "lon": -117.93269,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400935.0,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.000002,
#         "country": "US",
#         "address": "206 33RD STREET",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Newport Beach Simplicity I & Ii",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Newport Beach Chic I & Ii - Newport Beach, CA",
#         "id": "86220506",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.6176,
#         "lon": -117.93305,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400935.0,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.000002,
#         "country": "US",
#         "address": "312 36TH ST A",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Newport Beach Chic I & Ii",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Perfect Newport Beach Location With SPA I & Ii - Newport Beach, CA",
#         "id": "86205706",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.61413,
#         "lon": -117.93191,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400935.0,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.003693,
#         "country": "US",
#         "address": "3010 W BALBOA BLVD",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Perfect Newport Beach Location With SPA I & Ii",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Newport Temptation - Newport Beach, CA",
#         "id": "86199806",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.61878,
#         "lon": -117.93762,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.94,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.000002,
#         "country": "US",
#         "address": "4100 SEASHORE DR ",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Newport Temptation",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Newport Pacific I & Ii - Newport Beach, CA",
#         "id": "86209706",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.62137,
#         "lon": -117.93941,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.94,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "125 46TH ST UNIT A",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Newport Pacific I & Ii",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "NB Breaking Waves Beauty I & Ii - Slp13891 & Slp13892 - Newport Beach, CA",
#         "id": "86200706",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.60965,
#         "lon": -117.92968,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.9,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "2214 W OCEANFRONT UNIT A",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "NB Breaking Waves Beauty I & Ii - Slp13891 & Slp13892",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Oceanfront Balboa Boardwalk Units I, Ii, & Iii - Newport Beach, CA",
#         "id": "86203606",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.6011,
#         "lon": -117.89851,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.9,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "US",
#         "address": "906 E OCEANFRONT UNIT B",
#         "zip": "92661",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Oceanfront Balboa Boardwalk Units I, Ii, & Iii",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Balboa Island Diamond Resort Compound - Newport Beach, CA",
#         "id": "86211506",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.60486,
#         "lon": -117.89403,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.9,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.001848,
#         "country": "US",
#         "address": "126 DIAMOND AVE",
#         "zip": "92662",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Balboa Island Diamond Resort Compound",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "The Rivprime Water Front - Newport Beach, CA",
#         "id": "165741304",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.61884,
#         "lon": -117.93518,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.9,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "US",
#         "address": "null",
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "The Rivprime Water Front",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Modern Luxury Compound - Newport Beach, CA",
#         "id": "86219306",
#         "cityID": "3000002060",
#         "type": "HOTEL",
#         "lat": 33.61285,
#         "lon": -117.93113,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Newport Beach",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400934.9,
#         "radius": 24.5,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "128 29TH STREET",
#         "zip": "92663",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "newport beach ca",
#         "highlightedName": null,
#         "displayLine1": "Modern Luxury Compound",
#         "displayLine2": "Newport Beach, California",
#         "fromSavedSearch": false
#     }
# ]
# Hotel data for Napa, CA:
# [
#     {
#         "itemName": "Hennessey House Bed And Breakfast - Napa, CA",
#         "id": "4536805",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.3044,
#         "lon": -122.28973,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400992.1,
#         "radius": 44.6,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.018465,
#         "country": "US",
#         "address": "1727 MAIN STREET",
#         "zip": "94559",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Hennessey House Bed And Breakfast",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Silverado Golf Course - Napa, CA",
#         "id": "147643504",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.35994,
#         "lon": -122.26403,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400987.97,
#         "radius": 44.6,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.0,
#         "country": "US",
#         "address": "85 Fairways Drive",
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Silverado Golf Course",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "702 Cottages At Silverado Condo - Napa, CA",
#         "id": "122035703",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.35359,
#         "lon": -122.2649,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400987.97,
#         "radius": 44.6,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "null",
#         "zip": "94558",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "702 Cottages At Silverado Condo",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "703 Cottages At Silverado Residence - Napa, CA",
#         "id": "122040303",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.35346,
#         "lon": -122.26533,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400987.97,
#         "radius": 44.6,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.000002,
#         "country": "US",
#         "address": "null",
#         "zip": "94558",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "703 Cottages At Silverado Residence",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Inn On Randolph - Napa, CA",
#         "id": "46299306",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.292615,
#         "lon": -122.287015,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400987.97,
#         "radius": 44.6,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.00554,
#         "country": "US",
#         "address": "411 RANDOLPH ST",
#         "zip": "94559",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Inn On Randolph",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Pinzon P&G - Capital Federal, Argentina",
#         "id": "127620403",
#         "cityID": "5000497024",
#         "type": "HOTEL",
#         "lat": -34.63662,
#         "lon": -58.37016,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Capital Federal",
#         "stateCode": null,
#         "provinceName": null,
#         "score": 398967.28,
#         "radius": 33.6,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "ARGENTINA",
#         "address": "1230 PINZ\u00bfN APARTAMENTO",
#         "zip": null,
#         "countryName": "ARGENTINA",
#         "countryCode": "AR",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -3.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Pinzon P&G",
#         "displayLine2": "Capital Federal, Argentina",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Quality Inn Near Six Flags Discovery Kingdom-Napa Valley - Vallejo, CA",
#         "id": "43633",
#         "cityID": "3000002418",
#         "type": "HOTEL",
#         "lat": 38.13557,
#         "lon": -122.2136,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Vallejo",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 375053.16,
#         "radius": 55.2,
#         "rank": 11.810301,
#         "rank2": 74.03386688232422,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.5834,
#         "country": "US",
#         "address": "1185 ADMIRAL CALLAGHAN LANE",
#         "zip": "94591",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Quality Inn Near Six Flags Discovery Kingdom-Napa Valley",
#         "displayLine2": "Vallejo, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Embassy Suites BY Hilton Hotel Napa Valley - Napa, CA",
#         "id": "39373",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.2977200000001,
#         "lon": -122.30032,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 368351.38,
#         "radius": 44.6,
#         "rank": 13.47378,
#         "rank2": 66.86486053466797,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.928835,
#         "country": "US",
#         "address": "1075 CALIFORNIA BOULEVARD",
#         "zip": "94559",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Embassy Suites BY Hilton Hotel Napa Valley",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hotel Indigo Napa Valley - Napa, CA",
#         "id": "40664",
#         "cityID": "3000002049",
#         "type": "HOTEL",
#         "lat": 38.3349400000001,
#         "lon": -122.32164,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Napa",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 367725.34,
#         "radius": 44.6,
#         "rank": 12.018117,
#         "rank2": 66.37753295898438,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.51149,
#         "country": "US",
#         "address": "4195 SOLANO AVENUE",
#         "zip": "94558",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Hotel Indigo Napa Valley",
#         "displayLine2": "Napa, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Doubletree BY Hilton Hotel & SPA Napa Valley - American Canyon - American Canyon, CA",
#         "id": "10114304",
#         "cityID": "3000090026",
#         "type": "HOTEL",
#         "lat": 38.172821,
#         "lon": -122.253545,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "American Canyon",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 365207.97,
#         "radius": 51.7,
#         "rank": 12.049547,
#         "rank2": 65.99331665039062,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.491175,
#         "country": "US",
#         "address": "3600 BROADWAY STREET",
#         "zip": "94503",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "napa ca",
#         "highlightedName": null,
#         "displayLine1": "Doubletree BY Hilton Hotel & SPA Napa Valley - American Canyon",
#         "displayLine2": "American Canyon, California",
#         "fromSavedSearch": false
#     }
# ]
# Response type for Santa Monica, CA is not 'HOTEL'. Retrying...
# Response type for Santa Monica, CA is not 'HOTEL'. Retrying...
# Hotel data for Santa Monica, CA:
# [
#     {
#         "itemName": "Executive Santa Monica Suites - Los Angeles, CA",
#         "id": "177202703",
#         "cityID": "3000001947",
#         "type": "HOTEL",
#         "lat": 34.0485,
#         "lon": -118.45375,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 398968.22,
#         "radius": 22.3,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.001852,
#         "country": "US",
#         "address": "1418 BUTLER AVENUE",
#         "zip": "90025",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "santa monica ca",
#         "highlightedName": null,
# ...
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400569.7,
#         "radius": 22.3,
#         "rank": 1.0,
#         "rank2": 97.81724548339844,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.005552,
#         "country": "US",
#         "address": "BEETHOVEN STREET",
#         "zip": "90066",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "los angeles ca",
#         "highlightedName": null,
#         "displayLine1": "Deluxe Suites I 5min TO Venice Beach I Free Parking!",
#         "displayLine2": "Los Angeles, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Cozy Hollywood GET Away - Los Angeles, CA",
#         "id": "101370904",
#         "cityID": "3000001947",
#         "type": "HOTEL",
#         "lat": 34.099668,
#         "lon": -118.308387,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400569.7,
#         "radius": 22.3,
#         "rank": 1.0,
#         "rank2": 97.81724548339844,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.000006,
#         "country": "US",
#         "address": "5437 HAROLD WAY",
#         "zip": "90027",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "los angeles ca",
#         "highlightedName": null,
#         "displayLine1": "Cozy Hollywood GET Away",
#         "displayLine2": "Los Angeles, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Villa Aspen - Los Angeles, CA",
#         "id": "76861303",
#         "cityID": "3000001947",
#         "type": "HOTEL",
#         "lat": 34.10800915,
#         "lon": -118.36584249,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400568.75,
#         "radius": 22.3,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "7868 ELECTRA DR",
#         "zip": "90046",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "los angeles ca",
#         "highlightedName": null,
#         "displayLine1": "Villa Aspen",
#         "displayLine2": "Los Angeles, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Fashion Loft 2 Bedroom Downtown - Los Angeles, CA",
#         "id": "119753003",
#         "cityID": "3000001947",
#         "type": "HOTEL",
#         "lat": 34.04271,
#         "lon": -118.25375,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400568.75,
#         "radius": 22.3,
#         "rank": 0.5,
#         "rank2": 97.81620025634766,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.005543,
#         "country": "US",
#         "address": "814 SOUTH SPRING STREET",
#         "zip": "90014",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "los angeles ca",
#         "highlightedName": null,
#         "displayLine1": "Fashion Loft 2 Bedroom Downtown",
#         "displayLine2": "Los Angeles, California",
#         "fromSavedSearch": false
#     }
# ]
# Hotel data for San Francisco, CA:
# [
#     {
#         "itemName": "Canopy BY Hilton San Francisco Soma - San Francisco, CA",
#         "id": "119938704",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.782386,
#         "lon": -122.402097,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400674.56,
#         "radius": 19.8,
#         "rank": 1.0,
#         "rank2": 97.81724548339844,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.044365,
#         "country": "US",
#         "address": "250 4TH STREET",
#         "zip": "94103",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Canopy BY Hilton San Francisco Soma",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Beacon Grand, A Union Square Hotel - San Francisco, CA",
#         "id": "40550",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.788768,
#         "lon": -122.408532,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.7,
#         "radius": 19.8,
#         "rank": 16.019691,
#         "rank2": 97.8213882446289,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 32.01492,
#         "country": "US",
#         "address": "450 POWELL STREET",
#         "zip": "94102",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Beacon Grand, A Union Square Hotel",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Buena Vista Motor Inn - San Francisco, CA",
#         "id": "2185903",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.8009,
#         "lon": -122.427799,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.47,
#         "radius": 19.8,
#         "rank": 13.492216,
#         "rank2": 97.82112884521484,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.072018,
#         "country": "US",
#         "address": "1599 LOMBARD STREET",
#         "zip": "94123",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Buena Vista Motor Inn",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "LUZ Hotel - San Francisco, CA",
#         "id": "40959206",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.78617518,
#         "lon": -122.41530668,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.3,
#         "radius": 19.8,
#         "rank": 11.836448,
#         "rank2": 97.82093048095703,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.001848,
#         "country": "US",
#         "address": "725 GEARY STREET",
#         "zip": "94109",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "LUZ Hotel",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Civic Center Motor Inn - San Francisco, CA",
#         "id": "43023",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.772861,
#         "lon": -122.410534,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.3,
#         "radius": 19.8,
#         "rank": 11.862965,
#         "rank2": 97.82093811035156,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.965887,
#         "country": "US",
#         "address": "364 NINTH STREET",
#         "zip": "94103",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Civic Center Motor Inn",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Aldrich Hotel - San Francisco, CA",
#         "id": "41391104",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.78543568,
#         "lon": -122.41294026,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.3,
#         "radius": 19.8,
#         "rank": 11.840854,
#         "rank2": 97.82093048095703,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.03693,
#         "country": "US",
#         "address": "439 JONES STREET",
#         "zip": "94102",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Aldrich Hotel",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hotel Amari - San Francisco, CA",
#         "id": "42559",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.789009,
#         "lon": -122.410939,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.3,
#         "radius": 19.8,
#         "rank": 11.86696,
#         "rank2": 97.82093811035156,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "635 SUTTER STREET",
#         "zip": "94102",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Hotel Amari",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Elite Inn - San Francisco, CA",
#         "id": "31152804",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.7831655,
#         "lon": -122.4112249,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.3,
#         "radius": 19.8,
#         "rank": 11.862455,
#         "rank2": 97.82093811035156,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.09417,
#         "country": "US",
#         "address": "116 TURK STREET",
#         "zip": "94102",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Elite Inn",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Layne Hotel - San Francisco, CA",
#         "id": "2578205",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.786397,
#         "lon": -122.41312,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.25,
#         "radius": 19.8,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 30.0,
#         "globalScoreReducedCityBoost": 30.0,
#         "globalScoreWOHotelCountNormalize": 30.022158,
#         "country": "US",
#         "address": "545 JONES STREET",
#         "zip": "94102",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Layne Hotel",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Jackson Court - San Francisco, CA",
#         "id": "3637305",
#         "cityID": "3000002244",
#         "type": "HOTEL",
#         "lat": 37.792937,
#         "lon": -122.431066,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "San Francisco",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 400653.25,
#         "radius": 19.8,
#         "rank": 11.810301,
#         "rank2": 97.8209228515625,
#         "globalScore": 1.0,
#         "globalScoreReducedCityBoost": 1.0,
#         "globalScoreWOHotelCountNormalize": 1.0,
#         "country": "US",
#         "address": "2198 JACKSON STREET",
#         "zip": "94115",
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "san francisco ca",
#         "highlightedName": null,
#         "displayLine1": "Jackson Court",
#         "displayLine2": "San Francisco, California",
#         "fromSavedSearch": false
#     }
# ]

# %%
# Concatenate all DataFrames in the list into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#                                              itemName         id      cityID  \
# 0                       Roseview House - San Jose, CA  125194804  3000002250
# 1      Boutique Hotel Calle 20 - San Jose, Costa Rica   13453403  3000070002
# 2                Casa Lima B&B - San Jose, Costa Rica   42958406  3000070002
# 3    El Mirador Del Valle - San Jose Del Valle, Spain   23075205  5000371869
# 4                    La Caseta De Jose - Sueca, Spain   20960403  5000043954
# ..                                                ...        ...         ...
# 145                 Aldrich Hotel - San Francisco, CA   41391104  3000002244
# 146                   Hotel Amari - San Francisco, CA      42559  3000002244
# 147                     Elite Inn - San Francisco, CA   31152804  3000002244
# 148                   Layne Hotel - San Francisco, CA    2578205  3000002244
# 149                 Jackson Court - San Francisco, CA    3637305  3000002244
#
#       type        lat         lon  proximity savedTravelStartDate  \
# 0    HOTEL  37.330200 -121.897280        0.0                 None
# 1    HOTEL   9.937550  -84.087102        0.0                 None
# 2    HOTEL   9.945148  -84.125250        0.0                 None
# 3    HOTEL  36.612899   -5.804481        0.0                 None
# 4    HOTEL  39.248423   -0.260272        0.0                 None
# ..     ...        ...         ...        ...                  ...
# 145  HOTEL  37.785436 -122.412940        0.0                 None
# 146  HOTEL  37.789009 -122.410939        0.0                 None
# 147  HOTEL  37.783166 -122.411225        0.0                 None
# 148  HOTEL  37.786397 -122.413120        0.0                 None
# 149  HOTEL  37.792937 -122.431066        0.0                 None
#
#     savedTravelEndDate            cityName  ... poiCategoryTypeId  \
# 0                 None            San Jose  ...                 0
# 1                 None            San Jose  ...                 0
# 2                 None            San Jose  ...                 0
# 3                 None  San Jose Del Valle  ...                 0
# 4                 None               Sueca  ...                 0
# ..                 ...                 ...  ...               ...
# 145               None       San Francisco  ...                 0
# 146               None       San Francisco  ...                 0
# 147               None       San Francisco  ...                 0
# 148               None       San Francisco  ...                 0
# 149               None       San Francisco  ...                 0
#
#     poiCategoryName  poiID  seType  gmtOffset           entered  \
# 0              None   None    None       -7.0       san jose ca
# 1              None   None    None       -6.0       san jose ca
# 2              None   None    None       -6.0       san jose ca
# 3              None   None    None        2.0       san jose ca
# 4              None   None    None        2.0       san jose ca
# ..              ...    ...     ...        ...               ...
# 145            None   None    None       -7.0  san francisco ca
# 146            None   None    None       -7.0  san francisco ca
# 147            None   None    None       -7.0  san francisco ca
# 148            None   None    None       -7.0  san francisco ca
# 149            None   None    None       -7.0  san francisco ca
#
#      highlightedName             displayLine1               displayLine2  \
# 0               None           Roseview House       San Jose, California
# 1               None  Boutique Hotel Calle 20       San Jose, Costa Rica
# 2               None            Casa Lima B&B       San Jose, Costa Rica
# 3               None     El Mirador Del Valle  San Jose Del Valle, Spain
# 4               None        La Caseta De Jose               Sueca, Spain
# ..               ...                      ...                        ...
# 145             None            Aldrich Hotel  San Francisco, California
# 146             None              Hotel Amari  San Francisco, California
# 147             None                Elite Inn  San Francisco, California
# 148             None              Layne Hotel  San Francisco, California
# 149             None            Jackson Court  San Francisco, California
#
#     fromSavedSearch
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 145           False
# 146           False
# 147           False
# 148           False
# 149           False
#
# [150 rows x 34 columns]

# %%
final_df['name'] = final_df['displayLine1']
final_df['city'] = final_df['displayLine2'].str.split(',').str[0]
final_df['state'] = final_df['displayLine2'].str.split(',').str[1]

column_to_select = ['name',
                    'id',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country' 
                    ]

# Drop rows where a certain value is present in a specific column
values_to_keep = 'US'  # Replace with the value you want to drop
column_to_check = 'country'   # Replace with the column name

filtered_df_country = final_df[final_df[column_to_check] == values_to_keep]

# Drop rows where a certain value is present in a specific column
values_to_keep = 'HOTEL'  # Replace with the value you want to drop
column_to_check = 'type'   # Replace with the column name

filtered_df_type = filtered_df_country[filtered_df_country[column_to_check] == values_to_keep]

hotel_data_select = filtered_df_type[column_to_select]

hotel_data_select
# Out:
#                                                   name         id  \
# 0                                       Roseview House  125194804
# 22           Hampton Inn BY Hilton Santa Cruz West, CA   21328006
# 23   Super 8 BY Wyndham Santa Cruz/Beach Boardwalk ...    1812805
# 24        La Quinta Inn & Suites BY Wyndham Santa Cruz      39120
# 25                              Comfort Inn Santa Cruz      43582
# ..                                                 ...        ...
# 160                             Civic Center Motor Inn      43023
# 161                                      Aldrich Hotel   41391104
# 162                                        Hotel Amari      42559
# 163                                        Layne Hotel    2578205
# 164                                      Jackson Court    3637305
#
#               city        state        lat         lon      score       rank  \
# 0         San Jose   California  37.330200 -121.897280  400809.66   1.000000
# 22      Santa Cruz   California  36.961063 -122.048920  175204.38  11.810301
# 23      Santa Cruz   California  36.966590 -122.018330  175204.36  11.810301
# 24      Santa Cruz   California  36.964360 -122.024280  175204.36  11.810301
# 25      Santa Cruz   California  36.984950 -122.023220  175204.36  11.810304
# ..             ...          ...        ...         ...        ...        ...
# 160  San Francisco   California  37.772861 -122.410534  400658.12  11.862965
# 161  San Francisco   California  37.785436 -122.412940  400658.12  11.840854
# 162  San Francisco   California  37.789009 -122.410939  400658.12  11.866960
# 163  San Francisco   California  37.786397 -122.413120  400658.06  11.810301
# 164  San Francisco   California  37.792937 -122.431066  400658.06  11.810301
#
#          rank2  globalScore country
# 0    97.817245          1.0      US
# 22   49.023651         30.0      US
# 23    6.002491         30.0      US
# 24    5.927703         30.0      US
# 25   66.405663         30.0      US
# ..         ...          ...     ...
# 160  97.820938         30.0      US
# 161  97.820930         30.0      US
# 162  97.820938          1.0      US
# 163  97.820923         30.0      US
# 164  97.820923          1.0      US
#
# [118 rows x 11 columns]

# %%
hotel_data_select.dtypes
# Out:
# name            object
# id              object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = hotel_data_select.isnull().sum()

print(null_counts)
# Out:
# name           0
# id             0
# city           0
# state          0
# lat            0
# lon            0
# score          0
# rank           0
# rank2          0
# globalScore    0
# country        0
# dtype: int64

# %%
# Create a folder named "data" if it doesn't exist
if not os.path.exists("data"):
    os.mkdir("data")

# Save DataFrame to a CSV file inside the "data" folder
file_path = os.path.join("data", "hotel.csv")
hotel_data_select.to_csv(file_path, index=False)

print("DataFrame saved to 'data/hotel.csv' file.")
# Out:
# DataFrame saved to 'data/hotel.csv' file.

# %%
url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/locations"

querystring = {"name":"UNITED STATES","search_type":"AIRPORT"}

headers = {
	"X-RapidAPI-Key": priceline_api_key,
	"X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    # Use json.dumps with 'indent' parameter to pretty-print the JSON data
    json_data = json.dumps(response.json(), indent=4)
    print(json_data)
else:
    print("Failed to get data. Status code:", response.status_code)
# Out:
# [
#     {
#         "itemName": "Orlando Intl Airport (MCO) , FL",
#         "id": "MCO",
#         "cityID": "3000003349",
#         "type": "AIRPORT",
#         "lat": 28.43113982264317,
#         "lon": -81.3092428479283,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Orlando",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 388071.66,
#         "radius": 33.7,
#         "rank": 56.13621,
#         "rank2": 86.16417694091797,
#         "globalScore": 78.25274,
#         "globalScoreReducedCityBoost": 62.42079,
#         "globalScoreWOHotelCountNormalize": 48.595905,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Orlando - Orlando Intl Airport (MCO)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Miami Intl Airport (MIA) , FL",
#         "id": "MIA",
#         "cityID": "3000003311",
#         "type": "AIRPORT",
#         "lat": 25.79507559880528,
#         "lon": -80.28296084528998,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Miami",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 387476.03,
#         "radius": 28.9,
#         "rank": 45.91389,
#         "rank2": 85.56851196289062,
#         "globalScore": 76.66467,
#         "globalScoreReducedCityBoost": 46.181736,
#         "globalScoreWOHotelCountNormalize": 39.20895,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Miami - Miami Intl Airport (MIA)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hollywood Intl Airport (FLL) , FL",
#         "id": "FLL",
#         "cityID": "3000003192",
#         "type": "AIRPORT",
#         "lat": 26.076856242450617,
#         "lon": -80.1512378481894,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Fort Lauderdale",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 385823.97,
#         "radius": 17.6,
#         "rank": 57.068672,
#         "rank2": 83.93750762939453,
#         "globalScore": 75.521675,
#         "globalScoreReducedCityBoost": 43.354076,
#         "globalScoreWOHotelCountNormalize": 37.50558,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Fort Lauderdale - Hollywood Intl Airport (FLL)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Hartsfield-Jackson Atlanta Intl Airport (ATL) , GA",
#         "id": "ATL",
#         "cityID": "3000003496",
#         "type": "AIRPORT",
#         "lat": 33.64064398331116,
#         "lon": -84.42246632355115,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Atlanta",
#         "stateCode": "GA",
#         "provinceName": "Georgia",
#         "score": 385106.66,
#         "radius": 37.0,
#         "rank": 42.474194,
#         "rank2": 83.23897552490234,
#         "globalScore": 76.96165,
#         "globalScoreReducedCityBoost": 51.29527,
#         "globalScoreWOHotelCountNormalize": 41.950603,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Atlanta - Hartsfield-Jackson Atlanta Intl Airport (ATL)",
#         "displayLine2": "Georgia",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Phoenix Sky Harbor Intl Airport (PHX) , AZ",
#         "id": "PHX",
#         "cityID": "3000001349",
#         "type": "AIRPORT",
#         "lat": 33.43546779687481,
#         "lon": -112.00379514445629,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Phoenix",
#         "stateCode": "AZ",
#         "provinceName": "Arizona",
#         "score": 384922.3,
#         "radius": 36.7,
#         "rank": 47.539833,
#         "rank2": 83.06039428710938,
#         "globalScore": 74.87271,
#         "globalScoreReducedCityBoost": 42.74244,
#         "globalScoreWOHotelCountNormalize": 37.122154,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Phoenix - Phoenix Sky Harbor Intl Airport (PHX)",
#         "displayLine2": "Arizona",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Tampa Intl Airport (TPA) , FL",
#         "id": "TPA",
#         "cityID": "3000003431",
#         "type": "AIRPORT",
#         "lat": 27.980050150536673,
#         "lon": -82.53468498015411,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Tampa",
#         "stateCode": "FL",
#         "provinceName": "Florida",
#         "score": 384829.53,
#         "radius": 21.6,
#         "rank": 46.03609,
#         "rank2": 82.97066497802734,
#         "globalScore": 75.06991,
#         "globalScoreReducedCityBoost": 41.70141,
#         "globalScoreWOHotelCountNormalize": 36.507195,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Tampa - Tampa Intl Airport (TPA)",
#         "displayLine2": "Florida",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "O'Hare Intl Airport (ORD) , IL",
#         "id": "ORD",
#         "cityID": "3000005381",
#         "type": "AIRPORT",
#         "lat": 41.9704762962616,
#         "lon": -87.9083988449066,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Chicago",
#         "stateCode": "IL",
#         "provinceName": "Illinois",
#         "score": 384373.72,
#         "radius": 21.7,
#         "rank": 46.816677,
#         "rank2": 82.53114318847656,
#         "globalScore": 76.78653,
#         "globalScoreReducedCityBoost": 47.541634,
#         "globalScoreWOHotelCountNormalize": 39.76,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -5.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Chicago - O'Hare Intl Airport (ORD)",
#         "displayLine2": "Illinois",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Seattle-Tacoma Intl Airport (SEA) , WA",
#         "id": "SEA",
#         "cityID": "3000023414",
#         "type": "AIRPORT",
#         "lat": 47.44927062064107,
#         "lon": -122.31113399152126,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Seattle",
#         "stateCode": "WA",
#         "provinceName": "Washington",
#         "score": 384369.6,
#         "radius": 28.0,
#         "rank": 41.146538,
#         "rank2": 82.52716827392578,
#         "globalScore": 74.76679,
#         "globalScoreReducedCityBoost": 42.604374,
#         "globalScoreWOHotelCountNormalize": 37.04834,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Seattle - Seattle-Tacoma Intl Airport (SEA)",
#         "displayLine2": "Washington",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "John F Kennedy Intl Airport (JFK) , NY",
#         "id": "JFK",
#         "cityID": "3000015923",
#         "type": "AIRPORT",
#         "lat": 40.639380746613675,
#         "lon": -73.77204034876185,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Jamaica",
#         "stateCode": "NY",
#         "provinceName": "New York",
#         "score": 383816.5,
#         "radius": 14.0,
#         "rank": 51.016113,
#         "rank2": 81.9969711303711,
#         "globalScore": 77.9219,
#         "globalScoreReducedCityBoost": 50.513313,
#         "globalScoreWOHotelCountNormalize": 41.390118,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -4.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Jamaica - John F Kennedy Intl Airport (JFK)",
#         "displayLine2": "New York",
#         "fromSavedSearch": false
#     },
#     {
#         "itemName": "Los Angeles Intl Airport (LAX) , CA",
#         "id": "LAX",
#         "cityID": "3000001947",
#         "type": "AIRPORT",
#         "lat": 33.94310840336072,
#         "lon": -118.41060920960915,
#         "proximity": 0.0,
#         "savedTravelStartDate": null,
#         "savedTravelEndDate": null,
#         "cityName": "Los Angeles",
#         "stateCode": "CA",
#         "provinceName": "California",
#         "score": 383285.62,
#         "radius": 22.3,
#         "rank": 58.362736,
#         "rank2": 81.49127960205078,
#         "globalScore": 76.51697,
#         "globalScoreReducedCityBoost": 44.505028,
#         "globalScoreWOHotelCountNormalize": 38.192566,
#         "country": "US",
#         "address": null,
#         "zip": null,
#         "countryName": "UNITED STATES",
#         "countryCode": "US",
#         "poiCategoryTypeId": 0,
#         "poiCategoryName": null,
#         "poiID": null,
#         "seType": null,
#         "gmtOffset": -7.0,
#         "entered": "united states",
#         "highlightedName": null,
#         "displayLine1": "Los Angeles - Los Angeles Intl Airport (LAX)",
#         "displayLine2": "California",
#         "fromSavedSearch": false
#     }
# ]

# %%
dictionary_data = json.loads(response.text)

airport_data = pd.DataFrame(dictionary_data)

airport_data
# Out:
#                                             itemName   id      cityID  \
# 0                    Orlando Intl Airport (MCO) , FL  MCO  3000003349
# 1                      Miami Intl Airport (MIA) , FL  MIA  3000003311
# 2                  Hollywood Intl Airport (FLL) , FL  FLL  3000003192
# 3  Hartsfield-Jackson Atlanta Intl Airport (ATL) ...  ATL  3000003496
# 4         Phoenix Sky Harbor Intl Airport (PHX) , AZ  PHX  3000001349
#
#       type        lat         lon  proximity savedTravelStartDate  \
# 0  AIRPORT  28.431140  -81.309243        0.0                 None
# 1  AIRPORT  25.795076  -80.282961        0.0                 None
# 2  AIRPORT  26.076856  -80.151238        0.0                 None
# 3  AIRPORT  33.640644  -84.422466        0.0                 None
# 4  AIRPORT  33.435468 -112.003795        0.0                 None
#
#   savedTravelEndDate         cityName  ... poiCategoryTypeId poiCategoryName  \
# 0               None          Orlando  ...                 0            None
# 1               None            Miami  ...                 0            None
# 2               None  Fort Lauderdale  ...                 0            None
# 3               None          Atlanta  ...                 0            None
# 4               None          Phoenix  ...                 0            None
#
#    poiID  seType  gmtOffset        entered  highlightedName  \
# 0   None    None       -4.0  united states             None
# 1   None    None       -4.0  united states             None
# 2   None    None       -4.0  united states             None
# 3   None    None       -4.0  united states             None
# 4   None    None       -7.0  united states             None
#
#                                         displayLine1  displayLine2  \
# 0               Orlando - Orlando Intl Airport (MCO)       Florida
# 1                   Miami - Miami Intl Airport (MIA)       Florida
# 2     Fort Lauderdale - Hollywood Intl Airport (FLL)       Florida
# 3  Atlanta - Hartsfield-Jackson Atlanta Intl Airp...       Georgia
# 4    Phoenix - Phoenix Sky Harbor Intl Airport (PHX)       Arizona
#
#   fromSavedSearch
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 34 columns]

# %%
airport_data.columns
# Out:
# Index(['itemName', 'id', 'cityID', 'type', 'lat', 'lon', 'proximity',
#        'savedTravelStartDate', 'savedTravelEndDate', 'cityName', 'stateCode',
#        'provinceName', 'score', 'radius', 'rank', 'rank2', 'globalScore',
#        'globalScoreReducedCityBoost', 'globalScoreWOHotelCountNormalize',
#        'country', 'address', 'zip', 'countryName', 'countryCode',
#        'poiCategoryTypeId', 'poiCategoryName', 'poiID', 'seType', 'gmtOffset',
#        'entered', 'highlightedName', 'displayLine1', 'displayLine2',
#        'fromSavedSearch'],
#       dtype='object')

# %%
airport_data['name'] = airport_data['itemName'].str.split(',').str[0]
airport_data['city'] = airport_data['cityName']
airport_data['state'] = airport_data['displayLine2']

column_to_select = ['name',
                    'id',
                    'city',
                    'state',
                    'lat',
                    'lon',
                    'score', 
                    'rank', 
                    'rank2', 
                    'globalScore',
                    'country' 
                    ]

airport_data_select = airport_data[column_to_select]

airport_data_select.head()
# Out:
#                                              name   id             city  \
# 0                     Orlando Intl Airport (MCO)   MCO          Orlando
# 1                       Miami Intl Airport (MIA)   MIA            Miami
# 2                   Hollywood Intl Airport (FLL)   FLL  Fort Lauderdale
# 3  Hartsfield-Jackson Atlanta Intl Airport (ATL)   ATL          Atlanta
# 4          Phoenix Sky Harbor Intl Airport (PHX)   PHX          Phoenix
#
#      state        lat         lon      score       rank      rank2  \
# 0  Florida  28.431140  -81.309243  388071.66  56.136210  86.164177
# 1  Florida  25.795076  -80.282961  387476.03  45.913890  85.568512
# 2  Florida  26.076856  -80.151238  385823.97  57.068672  83.937508
# 3  Georgia  33.640644  -84.422466  385106.66  42.474194  83.238976
# 4  Arizona  33.435468 -112.003795  384922.30  47.539833  83.060394
#
#    globalScore country
# 0    78.252740      US
# 1    76.664670      US
# 2    75.521675      US
# 3    76.961650      US
# 4    74.872710      US

# %%
airport_data_select.dtypes
# Out:
# name            object
# id              object
# city            object
# state           object
# lat            float64
# lon            float64
# score          float64
# rank           float64
# rank2          float64
# globalScore    float64
# country         object
# dtype: object

# %%
null_counts = airport_data_select.isnull().sum()

print(null_counts)
# Out:
# name           0
# id             0
# city           0
# state          0
# lat            0
# lon            0
# score          0
# rank           0
# rank2          0
# globalScore    0
# country        0
# dtype: int64

# %%
# Create a folder named "data" if it doesn't exist
if not os.path.exists("data"):
    os.mkdir("data")

# Save DataFrame to a CSV file inside the "data" folder
file_path = os.path.join("data", "airport.csv")
airport_data_select.to_csv(file_path, index=False)

print("DataFrame saved to 'data/airport.csv' file.")
# Out:
# DataFrame saved to 'data/airport.csv' file.

# %%
test = hotel_data_select.copy()

test["price"] = ""

# %%
for index, row in test.iterrows():
    
    url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/booking-details"
    
    date_checkin = "2023-10-18"
    date_checkout = "2023-10-19"
    hotel_id = row["id"]
    rooms_number = "1"

    querystring = {"date_checkin": date_checkin,"hotel_id": hotel_id,"date_checkout": date_checkout,"rooms_number": rooms_number}

    headers = {
	    "X-RapidAPI-Key": priceline_api_key,
	    "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)
    
    response = response.json()

    try:
        test.loc[index, "price"] = response["rooms"][0]["displayableRates"][0]["displayPrice"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        test.loc[index, "price"] = "No price found"
    
    print(f"{test.loc[index, 'id']} - price: {test.loc[index, 'price']}")
# Out:
# 125194804 - price: No price found
# 21328006 - price: 153.33
# 1812805 - price: 145.35
# 39120 - price: 154.70
# 43582 - price: 90.99
# 4325605 - price: 531.00
# 43966504 - price: 152.00
# 86220506 - price: No price found
# 86227506 - price: No price found
# 86205706 - price: No price found
# 86199806 - price: No price found
# 86209706 - price: No price found
# 165741304 - price: No price found
# 86203606 - price: No price found
# 86200706 - price: No price found
# 86219306 - price: No price found
# 86211506 - price: No price found
# 4536805 - price: No price found
# 122035703 - price: No price found
# 46299306 - price: 470.35
# 147643504 - price: 719.98
# 122040303 - price: No price found
# 43633 - price: 77.85
# 39373 - price: 339.00
# 40664 - price: 300.05
# 10114304 - price: 152.15
# 177202703 - price: No price found
# 39053 - price: 409.00
# 43607 - price: 209.20
# 9350505 - price: 649.00
# 17175204 - price: 539.10
# 43244 - price: 305.00
# 44061 - price: 179.10
# 39652 - price: 494.73
# 69378405 - price: 332.22
# 31380504 - price: 386.10
# 35908006 - price: No price found
# 29945705 - price: 137.61
# 45322505 - price: 90.00
# 131497003 - price: No price found
# 65781006 - price: No price found
# 39620 - price: 381.91
# 39820 - price: 173.40
# 43234 - price: 83.01
# 42760 - price: 407.15
# 4700605 - price: 79.99
# 25427003 - price: No price found
# 39087 - price: 135.00
# 43093 - price: 58.65
# 41461 - price: 71.91
# 18708704 - price: 69.99
# 40564 - price: No price found
# 17783004 - price: 104.95
# 40066 - price: 184.45
# 1495705 - price: 73.00
# 7075305 - price: 70.00
# 18150504 - price: 107.14
# 26336603 - price: No price found
# 40572 - price: 234.00
# 60024405 - price: No price found
# 86200406 - price: No price found
# 9580705 - price: 554.90
# 39499 - price: 376.28
# 40406 - price: 319.20
# 43196 - price: 238.70
# 147703604 - price: No price found
# 39032 - price: 300.60
# 41552 - price: 285.60
# 5477805 - price: 536.00
# 8556805 - price: 126.65
# 40625 - price: No price found
# 18707604 - price: 59.99
# 125346703 - price: No price found
# 17177404 - price: 67.49
# 125327303 - price: No price found
# 125932905 - price: No price found
# 3086105 - price: 99.00
# 40607605 - price: 110.00
# 156446003 - price: No price found
# 25785504 - price: No price found
# 40206904 - price: 99.00
# 4008105 - price: 52.79
# 64690903 - price: No price found
# 4312605 - price: 169.00
# 19795204 - price: 84.99
# 77504103 - price: 313.65
# 1518605 - price: No price found
# 43595 - price: No price found
# 43276 - price: No price found
# 10051304 - price: No price found
# 51721303 - price: No price found
# 80626204 - price: No price found
# 91219003 - price: No price found
# 116383803 - price: No price found
# 86201106 - price: No price found
# 43086 - price: No price found
# 44170 - price: No price found
# 39509 - price: No price found
# 172917303 - price: No price found
# 3238405 - price: No price found
# 41313 - price: No price found
# 17476603 - price: No price found
# 2556003 - price: No price found
# 101370904 - price: No price found
# 68975105 - price: No price found
# 42913903 - price: No price found
# 119753003 - price: No price found
# 158335503 - price: No price found
# 119938704 - price: No price found
# 40550 - price: No price found
# 2185903 - price: No price found
# 31152804 - price: No price found
# 40959206 - price: No price found
# 43023 - price: No price found
# 41391104 - price: No price found
# 42559 - price: No price found
# 2578205 - price: No price found
# 3637305 - price: No price found
#                                                   name         id  \
# 0                                       Roseview House  125194804
# 22           Hampton Inn BY Hilton Santa Cruz West, CA   21328006
# 23   Super 8 BY Wyndham Santa Cruz/Beach Boardwalk ...    1812805
# 24        La Quinta Inn & Suites BY Wyndham Santa Cruz      39120
# 25                              Comfort Inn Santa Cruz      43582
# ..                                                 ...        ...
# 160                             Civic Center Motor Inn      43023
# 161                                      Aldrich Hotel   41391104
# 162                                        Hotel Amari      42559
# 163                                        Layne Hotel    2578205
# 164                                      Jackson Court    3637305
#
#               city        state        lat         lon      score       rank  \
# 0         San Jose   California  37.330200 -121.897280  400809.66   1.000000
# 22      Santa Cruz   California  36.961063 -122.048920  175204.38  11.810301
# 23      Santa Cruz   California  36.966590 -122.018330  175204.36  11.810301
# 24      Santa Cruz   California  36.964360 -122.024280  175204.36  11.810301
# 25      Santa Cruz   California  36.984950 -122.023220  175204.36  11.810304
# ..             ...          ...        ...         ...        ...        ...
# 160  San Francisco   California  37.772861 -122.410534  400658.12  11.862965
# 161  San Francisco   California  37.785436 -122.412940  400658.12  11.840854
# 162  San Francisco   California  37.789009 -122.410939  400658.12  11.866960
# 163  San Francisco   California  37.786397 -122.413120  400658.06  11.810301
# 164  San Francisco   California  37.792937 -122.431066  400658.06  11.810301
#
#          rank2  globalScore country           price
# 0    97.817245          1.0      US  No price found
# 22   49.023651         30.0      US          153.33
# 23    6.002491         30.0      US          145.35
# 24    5.927703         30.0      US          154.70
# 25   66.405663         30.0      US           90.99
# ..         ...          ...     ...             ...
# 160  97.820938         30.0      US  No price found
# 161  97.820930         30.0      US  No price found
# 162  97.820938          1.0      US  No price found
# 163  97.820923         30.0      US  No price found
# 164  97.820923          1.0      US  No price found
#
# [118 rows x 12 columns]

# %%
# Drop rows where a certain value is present in a specific column
values_to_drop = 'No price found'  # Replace with the value you want to drop
column_to_check = 'price'   # Replace with the column name

filtered_test = test[test[column_to_check] != values_to_drop]

len(filtered_test)
# Out:
# 55

# %%
# Create a folder named "data" if it doesn't exist
if not os.path.exists("data"):
    os.mkdir("data")

# Save DataFrame to a CSV file inside the "data" folder
file_path = os.path.join("data", "hotel_price.csv")
filtered_test.to_csv(file_path, index=False)

print("DataFrame saved to 'data/hotel_price.csv' file.")
# Out:
# DataFrame saved to 'data/hotel_price.csv' file.
